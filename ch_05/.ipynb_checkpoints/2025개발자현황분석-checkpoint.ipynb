# %%
import pandas as pd

raw_data = pd.read_csv("D:\survey_2025\survey_reaults_public.csv")
raw_data.info()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[14], line 3
#       1 import pandas as pd
# ----> 3 raw_data = pd.read_csv("D://survey_2025//survey_reaults_public.csv")
#       4 raw_data.info()
#
# ...
