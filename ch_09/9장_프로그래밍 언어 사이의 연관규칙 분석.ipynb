# %% [markdown]
# ## 데이터 적재하기

# %%
# 판다스 라이브러리 탑재
import pandas as pd

# CSV 파일 읽어오기
raw_data = pd.read_csv("C:\data\survey_results_public.csv")

# 데이터프레임 정보 확인하기
raw_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 73268 entries, 0 to 73267
# Data columns (total 79 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   ResponseId                      73268 non-null  int64
#  1   MainBranch                      73268 non-null  object
#  2   Employment                      71709 non-null  object
#  3   RemoteWork                      58958 non-null  object
#  4   CodingActivities                58899 non-null  object
#  5   EdLevel                         71571 non-null  object
#  6   LearnCode                       71580 non-null  object
#  7   LearnCodeOnline                 50685 non-null  object
#  8   LearnCodeCoursesCert            29389 non-null  object
#  9   YearsCode                       71331 non-null  object
#  10  YearsCodePro                    51833 non-null  object
#  11  DevType                         61302 non-null  object
#  12  OrgSize                         51039 non-null  object
#  13  PurchaseInfluence               50969 non-null  object
#  14  BuyNewTool                      67963 non-null  object
#  15  Country                         71771 non-null  object
#  16  Currency                        51264 non-null  object
#  17  CompTotal                       38422 non-null  float64
#  18  CompFreq                        44425 non-null  object
#  19  LanguageHaveWorkedWith          70975 non-null  object
#  20  LanguageWantToWorkWith          67027 non-null  object
#  21  DatabaseHaveWorkedWith          60121 non-null  object
#  22  DatabaseWantToWorkWith          51014 non-null  object
#  23  PlatformHaveWorkedWith          49924 non-null  object
#  24  PlatformWantToWorkWith          40415 non-null  object
#  25  WebframeHaveWorkedWith          53544 non-null  object
#  26  WebframeWantToWorkWith          46122 non-null  object
#  27  MiscTechHaveWorkedWith          44992 non-null  object
#  28  MiscTechWantToWorkWith          36810 non-null  object
#  29  ToolsTechHaveWorkedWith         54171 non-null  object
#  30  ToolsTechWantToWorkWith         46566 non-null  object
#  31  NEWCollabToolsHaveWorkedWith    70347 non-null  object
#  32  NEWCollabToolsWantToWorkWith    64108 non-null  object
#  33  OpSysProfessional use           65503 non-null  object
#  34  OpSysPersonal use               70963 non-null  object
#  35  VersionControlSystem            71379 non-null  object
#  36  VCInteraction                   68156 non-null  object
#  37  VCHostingPersonal use           0 non-null      float64
#  38  VCHostingProfessional use       0 non-null      float64
#  39  OfficeStackAsyncHaveWorkedWith  46223 non-null  object
#  40  OfficeStackAsyncWantToWorkWith  32072 non-null  object
#  41  OfficeStackSyncHaveWorkedWith   62128 non-null  object
#  42  OfficeStackSyncWantToWorkWith   47688 non-null  object
#  43  Blockchain                      71071 non-null  object
#  44  NEWSOSites                      71365 non-null  object
#  45  SOVisitFreq                     70961 non-null  object
#  46  SOAccount                       71572 non-null  object
#  47  SOPartFreq                      58229 non-null  object
#  48  SOComm                          71408 non-null  object
#  49  Age                             70946 non-null  object
#  50  Gender                          70853 non-null  object
#  51  Trans                           70315 non-null  object
#  52  Sexuality                       66565 non-null  object
#  53  Ethnicity                       69474 non-null  object
#  54  Accessibility                   67244 non-null  object
#  55  MentalHealth                    66447 non-null  object
#  56  TBranch                         52670 non-null  object
#  57  ICorPM                          36283 non-null  object
#  58  WorkExp                         36769 non-null  float64
#  59  Knowledge_1                     35804 non-null  object
#  60  Knowledge_2                     34973 non-null  object
#  61  Knowledge_3                     35133 non-null  object
#  62  Knowledge_4                     35097 non-null  object
#  63  Knowledge_5                     35014 non-null  object
#  64  Knowledge_6                     34991 non-null  object
#  65  Knowledge_7                     34977 non-null  object
#  66  Frequency_1                     35371 non-null  object
#  67  Frequency_2                     35344 non-null  object
#  68  Frequency_3                     34515 non-null  object
#  69  TimeSearching                   36198 non-null  object
#  70  TimeAnswering                   36022 non-null  object
#  71  Onboarding                      35679 non-null  object
#  72  ProfessionalTech                34906 non-null  object
#  73  TrueFalse_1                     35819 non-null  object
#  74  TrueFalse_2                     35715 non-null  object
#  75  TrueFalse_3                     35749 non-null  object
#  76  SurveyLength                    70444 non-null  object
#  77  SurveyEase                      70508 non-null  object
#  78  ConvertedCompYearly             38071 non-null  float64
# dtypes: float64(5), int64(1), object(73)
# memory usage: 44.2+ MB

# %%
pip install wordcloud
# Out:
# Requirement already satisfied: wordcloud in c:\anaconda3\lib\site-packages (1.9.6)
# Requirement already satisfied: numpy>=1.19.3 in c:\users\user\appdata\roaming\python\python313\site-packages (from wordcloud) (2.4.3)
# Requirement already satisfied: pillow in c:\anaconda3\lib\site-packages (from wordcloud) (12.0.0)
# Requirement already satisfied: matplotlib in c:\anaconda3\lib\site-packages (from wordcloud) (3.10.6)
# Requirement already satisfied: contourpy>=1.0.1 in c:\anaconda3\lib\site-packages (from matplotlib->wordcloud) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\anaconda3\lib\site-packages (from matplotlib->wordcloud) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\anaconda3\lib\site-packages (from matplotlib->wordcloud) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\anaconda3\lib\site-packages (from matplotlib->wordcloud) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\user\appdata\roaming\python\python313\site-packages (from matplotlib->wordcloud) (26.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\anaconda3\lib\site-packages (from matplotlib->wordcloud) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\user\appdata\roaming\python\python313\site-packages (from matplotlib->wordcloud) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\user\appdata\roaming\python\python313\site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# 일부 데이터 확인하기
raw_data.head()
# Out:
#    ResponseId                                         MainBranch  \
# 0           1                                      None of these
# 1           2                     I am a developer by profession
# 2           3  I am not primarily a developer, but I write co...
# 3           4                     I am a developer by profession
# 4           5                     I am a developer by profession
#
#             Employment                            RemoteWork  \
# 0                  NaN                                   NaN
# 1  Employed, full-time                          Fully remote
# 2  Employed, full-time  Hybrid (some remote, some in-person)
# 3  Employed, full-time                          Fully remote
# 4  Employed, full-time  Hybrid (some remote, some in-person)
#
#                            CodingActivities  \
# 0                                       NaN
# 1  Hobby;Contribute to open-source projects
# 2                                     Hobby
# 3              I don’t code outside of work
# 4                                     Hobby
#
#                                            EdLevel  \
# 0                                              NaN
# 1                                              NaN
# 2  Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 3     Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 4     Bachelor’s degree (B.A., B.S., B.Eng., etc.)
#
#                                            LearnCode  \
# 0                                                NaN
# 1                                                NaN
# 2  Books / Physical media;Friend or family member...
# 3  Books / Physical media;School (i.e., Universit...
# 4  Other online resources (e.g., videos, blogs, f...
#
#                                      LearnCodeOnline LearnCodeCoursesCert  \
# 0                                                NaN                  NaN
# 1                                                NaN                  NaN
# 2  Technical documentation;Blogs;Programming Game...                  NaN
# 3                                                NaN                  NaN
# 4  Technical documentation;Blogs;Stack Overflow;O...                  NaN
#
#   YearsCode  ... TimeSearching TimeAnswering Onboarding ProfessionalTech  \
# 0       NaN  ...           NaN           NaN        NaN              NaN
# 1       NaN  ...           NaN           NaN        NaN              NaN
# 2        14  ...           NaN           NaN        NaN              NaN
# 3        20  ...           NaN           NaN        NaN              NaN
# 4         8  ...           NaN           NaN        NaN              NaN
#
#   TrueFalse_1 TrueFalse_2 TrueFalse_3           SurveyLength  \
# 0         NaN         NaN         NaN                    NaN
# 1         NaN         NaN         NaN               Too long
# 2         NaN         NaN         NaN  Appropriate in length
# 3         NaN         NaN         NaN  Appropriate in length
# 4         NaN         NaN         NaN               Too long
#
#                    SurveyEase ConvertedCompYearly
# 0                         NaN                 NaN
# 1                   Difficult                 NaN
# 2  Neither easy nor difficult             40205.0
# 3                        Easy            215232.0
# 4                        Easy                 NaN
#
# [5 rows x 79 columns]

# %% [markdown]
# ## 데이터 분석가 데이터만 추출하기

# %%
# 개발자 타입 열 데이터 확인하기
raw_data['DevType']
# Out:
# 0                                                      NaN
# 1                                                      NaN
# 2        Data scientist or machine learning specialist;...
# 3                                    Developer, full-stack
# 4        Developer, front-end;Developer, full-stack;Dev...
#                                ...
# 73263                                  Developer, back-end
# 73264        Data scientist or machine learning specialist
# 73265    Developer, full-stack;Developer, desktop or en...
# 73266    Developer, front-end;Developer, desktop or ent...
# 73267    Developer, front-end;Engineer, data;Engineer, ...
# Name: DevType, Length: 73268, dtype: object

# %%
# 문자열을 리스트로 변환
dev_type = raw_data['DevType'].str.split(';')

# 결손치 제거
dev_type.dropna(inplace=True)
dev_type
# Out:
# 2        [Data scientist or machine learning specialist...
# 3                                  [Developer, full-stack]
# 4        [Developer, front-end, Developer, full-stack, ...
# 7                         [Developer, full-stack, Student]
# 8                                    [Developer, back-end]
#                                ...
# 73263                                [Developer, back-end]
# 73264      [Data scientist or machine learning specialist]
# 73265    [Developer, full-stack, Developer, desktop or ...
# 73266    [Developer, front-end, Developer, desktop or e...
# 73267    [Developer, front-end, Engineer, data, Enginee...
# Name: DevType, Length: 61302, dtype: object

# %%
# 리스트 항목을 각 행으로 나누기
exploded_dev_type=dev_type.explode()
exploded_dev_type
# Out:
# 2        Data scientist or machine learning specialist
# 2                                 Developer, front-end
# 2                                       Engineer, data
# 2                           Engineer, site reliability
# 3                                Developer, full-stack
#                              ...
# 73267                         Data or business analyst
# 73267                                         Designer
# 73267                                        Scientist
# 73267                                  Product manager
# 73267                             System administrator
# Name: DevType, Length: 164790, dtype: object

# %%
# 유일한 값 확인하기
exploded_dev_type.unique()
# Out:
# array(['Data scientist or machine learning specialist',
#        'Developer, front-end', 'Engineer, data',
#        'Engineer, site reliability', 'Developer, full-stack',
#        'Developer, back-end',
#        'Developer, desktop or enterprise applications',
#        'Developer, QA or test', 'Student', 'Developer, mobile',
#        'Educator', 'Engineering manager', 'Database administrator',
#        'Academic researcher', 'DevOps specialist',
#        'Other (please specify):',
#        'Developer, embedded applications or devices',
#        'Developer, game or graphics', 'Project manager',
#        'Cloud infrastructure engineer', 'Data or business analyst',
#        'Designer', 'Scientist', 'Product manager',
#        'Senior Executive (C-Suite, VP, etc.)', 'System administrator',
#        'Blockchain', 'Marketing or sales professional',
#        'Security professional'], dtype=object)

# %%
# 데이터 분석가 데이터만 추출하기
data_analyst_data = raw_data[raw_data['DevType'].isin(['Data scientist or machine learning specialist',
                                                       'Data or business analyst'])]

# 데이터 타입 항목 값 확인하기
data_analyst_data['DevType']
# Out:
# 240                           Data or business analyst
# 400                           Data or business analyst
# 463      Data scientist or machine learning specialist
# 1089     Data scientist or machine learning specialist
# 1704     Data scientist or machine learning specialist
#                              ...
# 73053                         Data or business analyst
# 73054                         Data or business analyst
# 73064    Data scientist or machine learning specialist
# 73204                         Data or business analyst
# 73264    Data scientist or machine learning specialist
# Name: DevType, Length: 742, dtype: object

# %% [markdown]
# ## 프로그래밍 언어 데이터만 추출하기

# %%
# 프로그래밍 언어 데이터 추출
languages=data_analyst_data['LanguageHaveWorkedWith']
languages
# Out:
# 240                   HTML/CSS;Python;Ruby;SQL;VBA
# 400                      Bash/Shell;C++;Python;SQL
# 463                          Bash/Shell;Python;SQL
# 1089                                        Python
# 1704             Elixir;Python;Rust;SQL;TypeScript
#                            ...
# 73053                        PowerShell;Python;SQL
# 73054                                            R
# 73064                        Java;Python;Scala;SQL
# 73204          Bash/Shell;HTML/CSS;Julia;R;SQL;VBA
# 73264    Bash/Shell;HTML/CSS;JavaScript;Python;SQL
# Name: LanguageHaveWorkedWith, Length: 742, dtype: object

# %%
# 데이터 문자열 변환 후 구분자(;)로 구분
languages = languages.str.split(";")
languages
# Out:
# 240                   [HTML/CSS, Python, Ruby, SQL, VBA]
# 400                       [Bash/Shell, C++, Python, SQL]
# 463                            [Bash/Shell, Python, SQL]
# 1089                                            [Python]
# 1704             [Elixir, Python, Rust, SQL, TypeScript]
#                               ...
# 73053                          [PowerShell, Python, SQL]
# 73054                                                [R]
# 73064                         [Java, Python, Scala, SQL]
# 73204         [Bash/Shell, HTML/CSS, Julia, R, SQL, VBA]
# 73264    [Bash/Shell, HTML/CSS, JavaScript, Python, SQL]
# Name: LanguageHaveWorkedWith, Length: 742, dtype: object

# %%
# 리스트 항목을 행으로 나누기 
exploded_languages = languages.explode()
exploded_languages
# Out:
# 240        HTML/CSS
# 240          Python
# 240            Ruby
# 240             SQL
# 240             VBA
#             ...
# 73264    Bash/Shell
# 73264      HTML/CSS
# 73264    JavaScript
# 73264        Python
# 73264           SQL
# Name: LanguageHaveWorkedWith, Length: 2566, dtype: object

# %%
# 프로그래밍별 응답 수 구하기
size_by_languages = exploded_languages.groupby(exploded_languages).size()

# 데이터 빈도 역순으로 정렬
size_by_languages.sort_values(ascending=False, inplace=True)
size_by_languages
# Out:
# LanguageHaveWorkedWith
# Python         624
# SQL            440
# R              213
# Bash/Shell     174
# JavaScript     169
# HTML/CSS       147
# C++            113
# Java            85
# VBA             70
# C               66
# C#              50
# PowerShell      46
# TypeScript      41
# MATLAB          41
# Julia           39
# SAS             33
# Scala           29
# Go              22
# Rust            22
# PHP             16
# Swift           10
# Kotlin          10
# Ruby             9
# Dart             9
# Assembly         8
# Haskell          8
# Lua              8
# Perl             7
# LISP             7
# Clojure          6
# APL              5
# Objective-C      5
# Solidity         4
# Groovy           4
# Fortran          3
# Elixir           2
# Delphi           2
# F#               2
# Crystal          1
# COBOL            1
# Erlang           1
# OCaml            1
# Name: LanguageHaveWorkedWith, dtype: int64

# %%
# 데이터프레임 만들기 위한 딕셔너리 만들기
frame={'language': size_by_languages.index, 'count':size_by_languages.values}

# 데이터프레임 만들기
size_by_languages_df = pd.DataFrame(frame)
size_by_languages_df.head()
# Out:
#      language  count
# 0      Python    624
# 1         SQL    440
# 2           R    213
# 3  Bash/Shell    174
# 4  JavaScript    169

# %% [markdown]
# ## 라이브러리 탑재 및 예시 확인

# %%
#매트플랏립 라이브러리 탑재
import matplotlib.pyplot as plt

# Wordcloud 라이브러리 탑재
from wordcloud import WordCloud

# %%
#데이터프레임 -> 딕셔너리로 변환
#클라우드는 딕셔너리로 바꿔서 사용해야하기떄문에 변환해야함.
size_by_languages.to_dict()
# Out:
# {'Python': 624,
#  'SQL': 440,
#  'R': 213,
#  'Bash/Shell': 174,
#  'JavaScript': 169,
#  'HTML/CSS': 147,
#  'C++': 113,
#  'Java': 85,
#  'VBA': 70,
#  'C': 66,
#  'C#': 50,
#  'PowerShell': 46,
#  'TypeScript': 41,
#  'MATLAB': 41,
#  'Julia': 39,
#  'SAS': 33,
#  'Scala': 29,
#  'Go': 22,
#  'Rust': 22,
#  'PHP': 16,
#  'Swift': 10,
#  'Kotlin': 10,
#  'Ruby': 9,
#  'Dart': 9,
#  'Assembly': 8,
#  'Haskell': 8,
#  'Lua': 8,
#  'Perl': 7,
#  'LISP': 7,
#  'Clojure': 6,
#  'APL': 5,
#  'Objective-C': 5,
#  'Solidity': 4,
#  'Groovy': 4,
#  'Fortran': 3,
#  'Elixir': 2,
#  'Delphi': 2,
#  'F#': 2,
#  'Crystal': 1,
#  'COBOL': 1,
#  'Erlang': 1,
#  'OCaml': 1}

# %%
#워드 클라우드 만들기
wordcloud = WordCloud(background_color = 'white').generate_from_frequencies(size_by_languages.to_dict())
wordcloud

# %%
#워드클라우드 그리기
plt.rcParams['figure.figsize'] = (10,10)
plt.imshow(wordcloud)
plt.axis('off')
plt.show()

# %% [markdown]
# ## 트리맵

# %%
# plotly.express 모듕 탑재
import plotly.express as px

# 트리맵 그리기
fig = px.treemap(size_by_languages_df, path=['language'], values='count')
fig.show()

# %%
pip install plotly
# Out:
# Requirement already satisfied: plotly in c:\anaconda3\lib\site-packages (6.3.0)
# Requirement already satisfied: narwhals>=1.15.1 in c:\anaconda3\lib\site-packages (from plotly) (2.7.0)
# Requirement already satisfied: packaging in c:\users\user\appdata\roaming\python\python313\site-packages (from plotly) (26.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## 데이터 학습 및 시각화

# %%
# 결손치 제거
languages.dropna(inplace = True)

# 필터링을 위한 리스트로 변환
lang_list = languages.to_list()

# 일부 값 확인 
lang_list[:10]
# Out:
# [['HTML/CSS', 'Python', 'Ruby', 'SQL', 'VBA'],
#  ['Bash/Shell', 'C++', 'Python', 'SQL'],
#  ['Bash/Shell', 'Python', 'SQL'],
#  ['Python'],
#  ['Elixir', 'Python', 'Rust', 'SQL', 'TypeScript'],
#  ['Python'],
#  ['Bash/Shell',
#   'C++',
#   'HTML/CSS',
#   'JavaScript',
#   'Python',
#   'Rust',
#   'SQL',
#   'TypeScript'],
#  ['Python', 'SQL'],
#  ['Bash/Shell', 'Go', 'HTML/CSS', 'Python'],
#  ['Bash/Shell', 'Python', 'Rust']]

# %%
# 추출 대상 프로그래밍 언어 선정
target_langs = ['Python', 'R', 'SQL', 'MATLAB', 'Go','SAS','Scala','Julia','Java','JavaScript']

# %%
#필터링 완료된 프로그래밍 언어를 담기 위한 리스트 생성
revised_lang_list=[]
#필터링을 위해 전체 리스트 순회
for lang in lang_list:
    filtered = [x for x in lang if x in target_langs]
    revised_lang_list.append(filtered)
#필터링 결과 화면
revised_lang_list
# Out:
# [['Python', 'SQL'],
#  ['Python', 'SQL'],
#  ['Python', 'SQL'],
#  ['Python'],
#  ['Python', 'SQL'],
#  ['Python'],
#  ['JavaScript', 'Python', 'SQL'],
#  ['Python', 'SQL'],
#  ['Go', 'Python'],
#  ['Python'],
#  ['Python'],
#  ['Go', 'Java'],
#  ['JavaScript', 'Python'],
#  ['Python', 'R', 'SQL'],
#  ['Julia', 'Python', 'R'],
#  ['Python', 'SQL'],
#  ['JavaScript', 'Python'],
#  ['Python', 'SQL'],
#  ['Julia', 'Python', 'R', 'SQL'],
#  ['Python'],
#  ['Python', 'R', 'SAS', 'SQL'],
#  ['Python'],
#  ['JavaScript', 'Python', 'SQL'],
#  ['JavaScript', 'Python', 'R', 'SAS', 'SQL'],
#  ['Python', 'Scala', 'SQL'],
#  ['Python', 'R'],
#  ['Python', 'R'],
#  ['JavaScript', 'Python', 'R', 'SQL'],
#  ['Python'],
#  ['Python'],
#  ['Python', 'R', 'SQL'],
#  ['JavaScript', 'Python'],
#  ['SQL'],
#  ['Python', 'R', 'SQL'],
#  ['Python', 'SQL'],
#  ['Python'],
#  ['Python', 'R', 'SQL'],
#  ['Python'],
#  ['Python'],
#  ['Julia', 'Python', 'R', 'SQL'],
#  ['Java', 'Python'],
#  ['Python'],
#  ['Python'],
#  ['JavaScript', 'Python', 'SQL'],
#  ['Java', 'JavaScript', 'Python'],
#  ['JavaScript', 'Python'],
#  ['Python', 'SQL'],
#  ['MATLAB', 'Python', 'R'],
#  ['Java', 'JavaScript', 'Python', 'SQL'],
#  ['MATLAB', 'Python', 'R', 'SQL'],
#  ['Python', 'SQL'],
#  ['Julia', 'Python', 'SQL'],
#  ['Python'],
#  ['Python'],
#  ['Python', 'SQL'],
#  ['Python'],
#  ['Python', 'SQL'],
#  ['Python', 'R', 'SQL'],
#  ['SQL'],
#  ['Python'],
#  ['Java', 'JavaScript', 'SQL'],
#  ['Python', 'SQL'],
#  ['Python', 'R', 'Scala', 'SQL'],
#  ['Python', 'R'],
#  ['Python'],
#  ['JavaScript', 'Python', 'SQL'],
#  ['Python', 'R', 'SQL'],
#  ['R'],
#  [],
#  ['Go', 'Python', 'SAS', 'SQL'],
#  ['Go', 'JavaScript', 'Python', 'SQL'],
#  ['Java', 'JavaScript', 'Python', 'SQL'],
#  ['Java', 'JavaScript', 'Python', 'R', 'SQL'],
#  ['Python', 'SQL'],
#  ['Python', 'R', 'SQL'],
#  ['JavaScript', 'SQL'],
#  ['Python'],
#  [],
#  ['Python'],
#  ['Python'],
#  ['Java', 'JavaScript', 'MATLAB', 'Python', 'SQL'],
#  ['JavaScript', 'Python', 'SQL'],
#  ['JavaScript', 'Python'],
#  ['Python', 'R', 'SQL'],
#  ['Python'],
#  ['Python'],
#  ['JavaScript', 'Python', 'SQL'],
#  ['Python', 'SQL'],
#  ['Java', 'JavaScript', 'Python', 'R', 'SQL'],
#  ['Python', 'Scala', 'SQL'],
#  ['Python', 'R'],
#  ['Go', 'JavaScript', 'Python'],
#  ['Python', 'R'],
#  ['Python', 'R', 'SAS', 'Scala', 'SQL'],
#  ['JavaScript', 'Python'],
#  ['MATLAB', 'Python'],
#  ['Python'],
#  ['Java', 'JavaScript', 'Python'],
#  ['Python', 'R', 'SQL'],
#  ['Python'],
#  ['R'],
#  ['Julia', 'SQL'],
#  ['Python'],
#  ['JavaScript', 'Python', 'SQL'],
#  ['Python', 'SQL'],
#  ['Python'],
#  ['Python', 'SQL'],
#  ['JavaScript', 'Julia', 'Python'],
#  ['JavaScript', 'Python', 'SQL'],
#  ['Python', 'R'],
#  ['Python', 'SQL'],
#  ['Python'],
#  ['Python', 'SQL'],
#  ['Python'],
#  ['Python', 'R'],
#  ['Python'],
#  ['JavaScript', 'Python'],
#  ['Java', 'MATLAB', 'Python', 'SAS', 'SQL'],
#  ['Julia', 'Python'],
#  ['R', 'SAS', 'SQL'],
#  ['Python', 'R', 'SQL'],
#  ['Python', 'R'],
#  ['JavaScript', 'Python', 'R', 'SQL'],
#  ['Julia', 'Python', 'R', 'SQL'],
#  ['MATLAB', 'Python', 'SQL'],
#  ['Python', 'SQL'],
#  ['Python', 'R'],
#  ['Java', 'JavaScript', 'Python', 'SAS', 'SQL'],
#  [],
#  ['Python', 'SAS', 'SQL'],
#  ['Python', 'R', 'SAS', 'SQL'],
#  ['JavaScript', 'Python'],
#  ['R', 'SQL'],
#  ['Python'],
#  ['Python', 'SQL'],
#  ['Julia', 'Python'],
#  ['Julia', 'Python'],
#  ['Python', 'R', 'SQL'],
#  ['JavaScript', 'Python', 'SQL'],
#  [],
#  ['Python', 'R', 'SQL'],
#  ['Python', 'R', 'SQL'],
#  ['Python', 'SQL'],
#  ['JavaScript', 'Julia', 'Python', 'SQL'],
#  ['Julia', 'Python', 'SQL'],
#  ['Python', 'R', 'SQL'],
#  ['JavaScript', 'Python'],
#  ['Julia', 'MATLAB', 'Python', 'R'],
#  ['Julia', 'Python', 'R', 'SQL'],
#  ['JavaScript', 'Python'],
#  ['Python'],
#  ['Python', 'R', 'SQL'],
#  ['SQL'],
#  ['Python', 'R', 'SAS'],
#  ['Python', 'R', 'SAS', 'SQL'],
#  ['Java', 'Python', 'SQL'],
#  ['JavaScript', 'Python', 'R', 'SQL'],
#  ['MATLAB', 'Python', 'R', 'SQL'],
#  ['Python', 'R', 'SQL'],
#  ['Java', 'JavaScript', 'Python', 'SQL'],
#  ['Java', 'JavaScript'],
#  ['Python', 'R'],
#  ['Python', 'SQL'],
#  ['Go', 'Python'],
#  ['Julia', 'Python'],
#  ['Python', 'SQL'],
#  ['Java'],
#  ['Python'],
#  ['JavaScript', 'SQL'],
#  ['JavaScript', 'Python', 'SQL'],
#  ['Python', 'R', 'SQL'],
#  ['Python', 'R', 'SAS', 'SQL'],
#  [],
#  ['MATLAB', 'Python', 'SQL'],
#  ['Python', 'R'],
#  ['JavaScript', 'Python'],
#  ['Java', 'JavaScript', 'Python', 'Scala', 'SQL'],
#  ['MATLAB', 'Python', 'R', 'SQL'],
#  ['SQL'],
#  ['R', 'SQL'],
#  ['MATLAB', 'Python'],
#  ['SQL'],
#  ['Python', 'SQL'],
#  ['Julia', 'Python', 'R', 'SQL'],
#  ['Java', 'Python', 'R', 'SQL'],
#  ['Python', 'R', 'SQL'],
#  [],
#  ['Python', 'SQL'],
#  ['Python'],
#  ['MATLAB', 'Python', 'SQL'],
#  ['Java', 'SQL'],
#  ['MATLAB', 'Python', 'SQL'],
#  ['Python', 'R', 'SAS', 'SQL'],
#  ['Julia', 'SQL'],
#  ['Python'],
#  ['R', 'SAS', 'SQL'],
#  ['Python', 'SQL'],
#  ['Python', 'SQL'],
#  ['SQL'],
#  ['Python'],
#  ['SQL'],
#  ['Python', 'SQL'],
#  ['Python', 'SQL'],
#  ['Python', 'SQL'],
#  ['Python', 'SQL'],
#  ['Java', 'JavaScript', 'Python', 'Scala', 'SQL'],
#  ['Go', 'Python', 'SQL'],
#  ['Python', 'R'],
#  ['Python'],
#  ['Julia', 'Python', 'R', 'Scala'],
#  ['Go', 'JavaScript', 'Python', 'R', 'SQL'],
#  ['Julia', 'Python', 'R', 'SQL'],
#  ['Go', 'Python'],
#  ['JavaScript', 'Julia', 'Python'],
#  ['Java', 'Python', 'SQL'],
#  ['Java', 'Python', 'SQL'],
#  ['MATLAB', 'Python', 'SQL'],
#  ['JavaScript', 'Python'],
#  ['JavaScript', 'Python', 'R', 'SQL'],
#  ['Python'],
#  ['Python', 'SQL'],
#  ['Python', 'SQL'],
#  ['JavaScript', 'Python', 'SQL'],
#  ['Java', 'Python', 'SQL'],
#  ['Python', 'SQL'],
#  ['Python'],
#  ['Python', 'R', 'SQL'],
#  ['Julia', 'Python', 'R', 'SQL'],
#  ['JavaScript', 'Python', 'SQL'],
#  ['Python'],
#  ['Python', 'R', 'SQL'],
#  ['Python'],
#  ['Java', 'Python', 'SQL'],
#  ['Python', 'R', 'SQL'],
#  ['Python', 'R'],
#  ['JavaScript', 'Python', 'SQL'],
#  ['Python', 'R'],
#  ['Python', 'R'],
#  ['Python', 'SAS', 'SQL'],
#  ['Java', 'JavaScript', 'MATLAB', 'Python', 'R', 'SQL'],
#  ['Java'],
#  ['Go', 'Python', 'Scala', 'SQL'],
#  ['JavaScript', 'Python', 'SQL'],
#  ['Python', 'SQL'],
#  ['Python'],
#  ['JavaScript', 'Python'],
#  ['Python', 'SQL'],
#  ['JavaScript', 'Python', 'SQL'],
#  ['Python', 'SQL'],
#  ['Java', 'JavaScript', 'Python', 'Scala', 'SQL'],
#  ['Python'],
#  ['JavaScript', 'Python'],
#  ['Python', 'SQL'],
#  ['JavaScript', 'Python', 'SQL'],
#  ['Python', 'SQL'],
#  ['Java'],
#  ['Python', 'R', 'SQL'],
#  ['Python'],
#  ['JavaScript', 'Python'],
#  ['JavaScript', 'Python'],
#  ['Python', 'SQL'],
#  ['Python', 'R', 'Scala'],
#  ['Java', 'JavaScript', 'Python'],
#  ['JavaScript', 'Python', 'SQL'],
#  ['Python', 'R', 'SQL'],
#  ['JavaScript', 'Python'],
#  ['Python', 'R', 'SAS', 'SQL'],
#  ['Go', 'Java', 'JavaScript', 'Python', 'SQL'],
#  ['Python', 'R', 'SQL'],
#  ['Python', 'SQL'],
#  ['R'],
#  ['Python', 'SQL'],
#  ['Python'],
#  ['Python'],
#  ['R', 'SQL'],
#  ['Python'],
#  ['Python', 'R', 'SQL'],
#  ['Python', 'SQL'],
#  ['Python', 'SQL'],
#  ['Java', 'JavaScript', 'Python', 'R', 'SAS', 'SQL'],
#  ['R', 'SQL'],
#  ['Python'],
#  ['JavaScript', 'Python'],
#  ['Python'],
#  ['Python', 'R', 'SQL'],
#  ['Python', 'SQL'],
#  ['MATLAB', 'Python', 'Scala', 'SQL'],
#  ['Python', 'SQL'],
#  ['Java', 'JavaScript', 'Python', 'SQL'],
#  ['Python'],
#  ['JavaScript', 'Python', 'SQL'],
#  ['Java', 'JavaScript', 'Python', 'SQL'],
#  ['R'],
#  ['Python'],
#  ['Python'],
#  ['R', 'SQL'],
#  ['Python', 'R', 'SQL'],
#  ['SQL'],
#  ['Python', 'SQL'],
#  ['Java', 'JavaScript', 'SQL'],
#  ['Python'],
#  ['JavaScript', 'Python'],
#  ['JavaScript', 'Python', 'SQL'],
#  ['Python', 'R', 'SQL'],
#  ['SQL'],
#  ['Python', 'SQL'],
#  ['R'],
#  ['Python'],
#  [],
#  ['Java', 'SQL'],
#  ['JavaScript'],
#  ['Python'],
#  ['Python', 'SQL'],
#  ['Python'],
#  ['Python'],
#  ['JavaScript', 'Python', 'SQL'],
#  ['JavaScript', 'MATLAB', 'Python', 'SQL'],
#  ['Python', 'R'],
#  ['Python', 'SQL'],
#  ['Python', 'R', 'SQL'],
#  ['Java', 'JavaScript', 'Python', 'R', 'SQL'],
#  ['Julia', 'Python', 'R'],
#  ['Python', 'SQL'],
#  ['Python'],
#  ['Python'],
#  ['Java', 'Python', 'R', 'SQL'],
#  ['Python', 'SQL'],
#  ['MATLAB', 'Python', 'R', 'SQL'],
#  ['JavaScript', 'Python'],
#  ['Python'],
#  ['Go', 'Python'],
#  ['Python', 'SQL'],
#  ['MATLAB', 'Python', 'R', 'SQL'],
#  ['Python', 'R'],
#  ['Java', 'JavaScript', 'MATLAB', 'Python', 'SQL'],
#  ['Java', 'JavaScript', 'Python'],
#  ['Python', 'SQL'],
#  ['R', 'SQL'],
#  ['Python', 'R', 'SQL'],
#  ['Python', 'SQL'],
#  ['Python', 'SQL'],
#  ['Python', 'SQL'],
#  ['Python'],
#  ['R', 'SQL'],
#  ['Python', 'R', 'SQL'],
#  ['JavaScript', 'Julia', 'Python'],
#  ['Java', 'JavaScript', 'Python'],
#  ['SQL'],
#  ['Python', 'R', 'SQL'],
#  ['JavaScript', 'Julia', 'Python', 'R', 'SQL'],
#  ['JavaScript', 'Python', 'R', 'SQL'],
#  ['JavaScript', 'Python'],
#  ['Python'],
#  ['Java', 'Python', 'Scala'],
#  ['Python', 'SQL'],
#  ['Python'],
#  ['SQL'],
#  ['Python'],
#  ['Python'],
#  ['Python', 'R', 'SQL'],
#  ['Python'],
#  ['Java', 'Python'],
#  ['JavaScript'],
#  ['Python'],
#  ['Python', 'SQL'],
#  ['Python'],
#  ['Python', 'R', 'SQL'],
#  ['Python', 'R', 'SQL'],
#  ['JavaScript', 'Python', 'R', 'SQL'],
#  ['JavaScript', 'Julia', 'Python', 'R', 'SQL'],
#  ['R'],
#  ['Python', 'SQL'],
#  ['Python'],
#  ['JavaScript', 'Julia', 'Python'],
#  ['Python'],
#  ['Python', 'SQL'],
#  ['Python', 'SQL'],
#  ['Python'],
#  ['R'],
#  ['Python', 'R', 'SQL'],
#  ['Python', 'R', 'SQL'],
#  ['Python', 'SQL'],
#  ['Python', 'R', 'SQL'],
#  ['Python', 'SQL'],
#  ['R'],
#  ['Python', 'R', 'SQL'],
#  ['SQL'],
#  ['Python'],
#  ['Python', 'SQL'],
#  ['Python', 'SQL'],
#  ['Python', 'R'],
#  ['JavaScript', 'Python', 'SQL'],
#  ['Python'],
#  ['Python', 'SQL'],
#  ['Python'],
#  ['Java', 'SQL'],
#  ['SQL'],
#  ['Python', 'R', 'SQL'],
#  ['JavaScript', 'Python', 'SQL'],
#  ['Java', 'JavaScript', 'Python', 'Scala', 'SQL'],
#  ['Python'],
#  ['SAS', 'SQL'],
#  ['R'],
#  ['Java', 'Python'],
#  ['Python', 'SQL'],
#  ['Python'],
#  ['Python', 'R', 'Scala', 'SQL'],
#  ['Python', 'R', 'SQL'],
#  ['Python', 'R', 'SQL'],
#  [],
#  ['JavaScript', 'Python'],
#  ['JavaScript', 'Python', 'SQL'],
#  ['Python', 'SQL'],
#  ['JavaScript', 'Python', 'R', 'SQL'],
#  ['Python', 'R', 'SQL'],
#  ['Python'],
#  ['Python'],
#  ['Julia', 'Python', 'R', 'SQL'],
#  ['Python'],
#  ['Java', 'SQL'],
#  ['JavaScript', 'Python', 'SQL'],
#  ['Python'],
#  ['MATLAB', 'Python', 'SQL'],
#  ['Python'],
#  ['Python'],
#  ['JavaScript', 'MATLAB', 'Python', 'R', 'SQL'],
#  ['Java', 'Python', 'SQL'],
#  [],
#  ['Julia', 'Python', 'Scala', 'SQL'],
#  ['Java', 'JavaScript', 'Python'],
#  ['JavaScript', 'SQL'],
#  ['Go', 'Python', 'R', 'Scala', 'SQL'],
#  ['Python', 'R', 'SQL'],
#  ['Java', 'JavaScript', 'Python', 'R', 'SQL'],
#  ['JavaScript', 'R', 'SQL'],
#  ['Python', 'SQL'],
#  ['Python', 'SQL'],
#  ['SQL'],
#  ['Python', 'SQL'],
#  ['Python', 'SQL'],
#  ['Python'],
#  ['MATLAB', 'Python', 'R', 'SQL'],
#  ['Python', 'Scala'],
#  ['Python'],
#  ['Java', 'Python'],
#  ['Go', 'Python', 'R', 'SQL'],
#  ['Python', 'SQL'],
#  ['Python', 'SQL'],
#  ['Python', 'SQL'],
#  ['R'],
#  ['Python', 'SQL'],
#  ['Java', 'Python', 'SQL'],
#  ['Python', 'R', 'Scala'],
#  ['Python'],
#  ['Java', 'JavaScript', 'Python', 'R', 'Scala', 'SQL'],
#  ['Python', 'SAS', 'SQL'],
#  ['Python'],
#  ['Python'],
#  ['Python', 'R'],
#  ['MATLAB', 'Python'],
#  ['Go', 'Java', 'JavaScript', 'Python'],
#  ['Python', 'R', 'SQL'],
#  ['Python', 'SQL'],
#  ['JavaScript', 'Python', 'R', 'SQL'],
#  [],
#  ['Python', 'SQL'],
#  ['R', 'SQL'],
#  ['JavaScript', 'Python', 'SQL'],
#  ['Python', 'SQL'],
#  ['Python'],
#  ['Java', 'Python'],
#  ['Go', 'Java', 'JavaScript', 'Python'],
#  ['Python', 'SQL'],
#  ['Java', 'R', 'SQL'],
#  ['Python'],
#  ['Python', 'R', 'SQL'],
#  ['Java', 'JavaScript', 'Python', 'Scala', 'SQL'],
#  ['Python', 'SQL'],
#  ['Python', 'SQL'],
#  ['Python', 'SQL'],
#  ['Python', 'R', 'SQL'],
#  ['JavaScript', 'Python', 'SQL'],
#  ['Python', 'SQL'],
#  ['Python', 'SQL'],
#  ['Python', 'SQL'],
#  ['Python'],
#  ['JavaScript', 'Python', 'R', 'SQL'],
#  ['Python'],
#  ['Python'],
#  ['Julia', 'Python'],
#  ['JavaScript', 'Python', 'SQL'],
#  ['Python', 'SQL'],
#  ['Java', 'Python', 'R'],
#  ['Python'],
#  ['Python'],
#  ['Python', 'SQL'],
#  ['Python', 'SQL'],
#  ['Java', 'Python', 'SQL'],
#  ['JavaScript', 'Python', 'R', 'SQL'],
#  ['JavaScript', 'Python', 'R', 'SQL'],
#  ['Python', 'SQL'],
#  ['Java', 'JavaScript', 'Python', 'SQL'],
#  ['Python', 'R', 'SQL'],
#  ['Python', 'SQL'],
#  ['Python', 'SQL'],
#  ['Java', 'JavaScript', 'Python', 'R', 'SQL'],
#  ['Python'],
#  ['Java', 'JavaScript', 'Python'],
#  ['SQL'],
#  ['Julia', 'Python', 'R', 'SQL'],
#  ['JavaScript', 'Python', 'SQL'],
#  ['Java', 'Python', 'SQL'],
#  ['Python', 'R', 'SQL'],
#  ['Python', 'R'],
#  ['Python', 'R'],
#  ['Python', 'SQL'],
#  ['JavaScript', 'Python', 'SQL'],
#  ['Python'],
#  ['Python'],
#  ['Java', 'JavaScript', 'Python', 'SQL'],
#  ['Python', 'SQL'],
#  ['Python'],
#  ['JavaScript', 'Python', 'SQL'],
#  ['JavaScript', 'SQL'],
#  ['SQL'],
#  ['Python', 'SQL'],
#  ['Python'],
#  ['JavaScript', 'Python', 'SQL'],
#  ['JavaScript', 'Python'],
#  ['Python'],
#  ['Python'],
#  ['Python', 'R'],
#  ['Python'],
#  ['Python'],
#  ['JavaScript', 'Python'],
#  ['JavaScript', 'Python', 'SQL'],
#  ['Python'],
#  ['Julia', 'R', 'SQL'],
#  ['JavaScript', 'Python'],
#  ['Python'],
#  ['Python', 'R', 'SQL'],
#  ['Python', 'SQL'],
#  ['JavaScript', 'Python', 'SAS', 'SQL'],
#  ['JavaScript'],
#  ['JavaScript'],
#  ['JavaScript', 'Python', 'R', 'SQL'],
#  ['MATLAB', 'Python', 'R', 'SAS', 'SQL'],
#  ['Go', 'Java', 'Python', 'SQL'],
#  ['Scala'],
#  ['SQL'],
#  ['Java', 'JavaScript', 'MATLAB', 'Python', 'SQL'],
#  ['Python', 'R', 'SQL'],
#  ['MATLAB', 'Python', 'R', 'SAS', 'Scala', 'SQL'],
#  ['Python', 'SQL'],
#  ['Python', 'R', 'SQL'],
#  ['Python'],
#  ['Java', 'Python', 'SQL'],
#  ['Java', 'Python'],
#  ['Python', 'SQL'],
#  ['Python'],
#  ['Python', 'R', 'SQL'],
#  ['R', 'SAS', 'SQL'],
#  ['JavaScript', 'Python', 'SQL'],
#  [],
#  ['Python', 'R'],
#  ['Python', 'R', 'SAS', 'SQL'],
#  ['Julia', 'Python'],
#  ['R', 'SQL'],
#  ['Go', 'JavaScript', 'Python', 'SQL'],
#  ['Python', 'SQL'],
#  ['Python', 'R', 'SQL'],
#  ['Python'],
#  ['Python', 'R', 'SAS', 'SQL'],
#  ['MATLAB', 'Python', 'R', 'SAS', 'SQL'],
#  [],
#  ['Python'],
#  ['Python', 'R'],
#  ['Go', 'JavaScript', 'Julia', 'Python', 'R', 'SAS', 'SQL'],
#  ['Python'],
#  [],
#  ['Python', 'SQL'],
#  ['Python', 'SQL'],
#  ['Java', 'JavaScript', 'Python', 'R', 'SQL'],
#  ['Python', 'R'],
#  ['R'],
#  ['Java', 'JavaScript', 'Python', 'SQL'],
#  ['Python'],
#  ['Python'],
#  ['SQL'],
#  ['Java', 'Python'],
#  ['JavaScript', 'Python', 'SQL'],
#  ['JavaScript', 'Python', 'SQL'],
#  ['MATLAB', 'Python'],
#  ['Java', 'Python', 'SAS', 'SQL'],
#  ['Python', 'SQL'],
#  ['Python'],
#  ['JavaScript', 'Python', 'SQL'],
#  ['Java', 'JavaScript', 'Python', 'R', 'Scala', 'SQL'],
#  ['Java', 'Python', 'R', 'Scala'],
#  ['JavaScript', 'Python', 'R', 'SQL'],
#  ['Python', 'R', 'SQL'],
#  ['JavaScript', 'Python', 'R', 'SQL'],
#  ['Python', 'SQL'],
#  ['JavaScript', 'SQL'],
#  ['R', 'SAS', 'SQL'],
#  ['Julia', 'R'],
#  ['JavaScript', 'Python', 'SQL'],
#  ['Python', 'SQL'],
#  ['Java', 'JavaScript', 'Python', 'SQL'],
#  ['Go', 'JavaScript', 'Python', 'SQL'],
#  ['Python'],
#  ['R'],
#  ['Python', 'R', 'SQL'],
#  ['Python', 'SAS', 'SQL'],
#  ['R', 'SQL'],
#  ['Python'],
#  ['JavaScript', 'Python', 'SQL'],
#  ['Python', 'SQL'],
#  ['Java', 'JavaScript', 'MATLAB', 'Python', 'SQL'],
#  ['MATLAB', 'Python'],
#  ['Python', 'R', 'Scala'],
#  ['Python'],
#  ['SAS', 'SQL'],
#  ['Python', 'SQL'],
#  ['Python'],
#  ['JavaScript', 'Python', 'R', 'Scala', 'SQL'],
#  ['Python', 'SQL'],
#  ['Python'],
#  ['JavaScript', 'Python', 'SQL'],
#  ['JavaScript', 'Python', 'R', 'SQL'],
#  ['R', 'SQL'],
#  ['Python', 'R', 'SQL'],
#  ['Python', 'R', 'SQL'],
#  ['Python', 'R', 'SQL'],
#  ['Python', 'SQL'],
#  ['Python'],
#  ['Python', 'SQL'],
#  ['SQL'],
#  ['JavaScript', 'MATLAB', 'Python', 'R', 'SQL'],
#  ['Python'],
#  ['MATLAB', 'Python', 'SQL'],
#  ['Python'],
#  ['Python', 'SQL'],
#  ['JavaScript', 'Python', 'SAS', 'SQL'],
#  ['Python', 'SQL'],
#  ['MATLAB', 'Python'],
#  ['MATLAB', 'Python', 'SQL'],
#  ['Python', 'SQL'],
#  ['Julia'],
#  ['Python', 'SQL'],
#  ['JavaScript', 'Python', 'SQL'],
#  ['Python', 'SQL'],
#  ['JavaScript'],
#  ['Python'],
#  ['Python'],
#  ['Java', 'JavaScript', 'Python'],
#  ['Java', 'JavaScript', 'Python'],
#  ['Python'],
#  ['MATLAB', 'Python'],
#  ['Julia', 'R'],
#  ['Python', 'SQL'],
#  ['Python', 'SQL'],
#  ['SQL'],
#  ['Python', 'SQL'],
#  ['R'],
#  ['R', 'SQL'],
#  ['Python'],
#  ['JavaScript', 'Julia', 'Python'],
#  ['JavaScript', 'SQL'],
#  ['Python', 'Scala', 'SQL'],
#  ['Java', 'JavaScript', 'Python', 'SQL'],
#  ['Python', 'SQL'],
#  ['Go', 'JavaScript', 'Python', 'R', 'SQL'],
#  ['JavaScript', 'Python'],
#  ['Python', 'SQL'],
#  ['SQL'],
#  ['Julia', 'MATLAB', 'Python', 'R', 'SAS', 'SQL'],
#  ['Python', 'SQL'],
#  ['Python', 'SQL'],
#  ['SQL'],
#  ['JavaScript', 'Python', 'SQL'],
#  ['Java', 'JavaScript', 'MATLAB', 'Python'],
#  ['Python'],
#  ['R'],
#  ['Python', 'SQL'],
#  ['Python', 'SQL'],
#  ['R', 'SQL'],
#  ['JavaScript', 'Python', 'SQL'],
#  ['Python', 'R'],
#  ['Python'],
#  ['Python', 'SQL'],
#  ['Python', 'R'],
#  ['SQL'],
#  ['Java', 'Python'],
#  ['Python'],
#  ['Python', 'SQL'],
#  ['Python', 'R', 'SQL'],
#  ['Python', 'R', 'SQL'],
#  ['Java', 'JavaScript', 'Python', 'SQL'],
#  ['Java', 'Python'],
#  ['MATLAB', 'Python', 'R'],
#  ['JavaScript', 'Python', 'R', 'Scala', 'SQL'],
#  ['JavaScript', 'Python'],
#  ['Python', 'SQL'],
#  ['Python', 'R', 'SQL'],
#  ['Python', 'R'],
#  ['JavaScript', 'Python', 'SQL'],
#  ['Python'],
#  ['Python', 'SQL'],
#  ['MATLAB', 'Python', 'SQL'],
#  ['Python', 'SQL'],
#  ['Java', 'SQL'],
#  ['Python', 'SQL'],
#  ['Python'],
#  ['Python', 'R', 'SQL'],
#  ['JavaScript', 'Python'],
#  ['Go', 'Python'],
#  ['R', 'SQL'],
#  ['Python', 'SQL'],
#  ['Python', 'SQL'],
#  ['R', 'SQL'],
#  ['MATLAB', 'Python', 'R', 'SQL'],
#  ['Python'],
#  ['Python'],
#  ['Python', 'SQL'],
#  ['R'],
#  ['Java', 'Python', 'Scala', 'SQL'],
#  ['Julia', 'R', 'SQL'],
#  ['JavaScript', 'Python', 'SQL']]

# %%
#데이터 전처리

#전처리 라이브러리 탑재
from mlxtend.preprocessing import TransactionEncoder
#전처리기 생성
te = TransactionEncoder()

#전처리 수행
te_ary = te.fit(revised_lang_list).transform(revised_lang_list)
te_ary
# Out:
# array([[False, False, False, ..., False,  True, False],
#        [False, False, False, ..., False,  True, False],
#        [False, False, False, ..., False,  True, False],
#        ...,
#        [False,  True, False, ..., False,  True,  True],
#        [False, False, False, ..., False,  True, False],
#        [False, False,  True, ..., False,  True, False]], shape=(729, 10))

# %%
# 전처리 결과를 데이터 프레임으로 변환
new_languages = pd.DataFrame(te_ary, columns=te.columns_)
new_languages
# Out:
#         Go   Java  JavaScript  Julia  MATLAB  Python      R    SAS    SQL  \
# 0    False  False       False  False   False    True  False  False   True
# 1    False  False       False  False   False    True  False  False   True
# 2    False  False       False  False   False    True  False  False   True
# 3    False  False       False  False   False    True  False  False  False
# 4    False  False       False  False   False    True  False  False   True
# ..     ...    ...         ...    ...     ...     ...    ...    ...    ...
# 724  False  False       False  False   False    True  False  False   True
# 725  False  False       False  False   False   False   True  False  False
# 726  False   True       False  False   False    True  False  False   True
# 727  False  False       False   True   False   False   True  False   True
# 728  False  False        True  False   False    True  False  False   True
#
#      Scala
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# ..     ...
# 724  False
# 725  False
# 726   True
# 727  False
# 728  False
#
# [729 rows x 10 columns]

# %% [markdown]
# ## 지지도 구하기

# %%
# 학습 알고리즘 탑재
from mlxtend.frequent_patterns import apriori, association_rules

# 지지도 구하기 
freq_items = apriori(new_languages, min_support=0.01, use_colnames=True, verbose=1)
# Out:
# Processing 55 combinations | Sampling itemset size 54

# %%
# 학습 결과 확인하기
freq_items.sort_values(['support'], ascending=False).head(20)
# Out:
#      support                    itemsets
# 5   0.855967                    (Python)
# 8   0.603567                       (SQL)
# 32  0.517147               (SQL, Python)
# 6   0.292181                         (R)
# 30  0.237311                 (Python, R)
# 2   0.231824                (JavaScript)
# 35  0.213992                    (SQL, R)
# 20  0.211248        (Python, JavaScript)
# 64  0.182442            (SQL, Python, R)
# 22  0.160494           (SQL, JavaScript)
# 53  0.148148   (SQL, Python, JavaScript)
# 1   0.116598                      (Java)
# 14  0.098765              (Python, Java)
# 16  0.076818                 (SQL, Java)
# 45  0.065844         (SQL, Python, Java)
# 13  0.064472          (JavaScript, Java)
# 41  0.060357  (Python, JavaScript, Java)
# 27  0.056241            (Python, MATLAB)
# 4   0.056241                    (MATLAB)
# 3   0.053498                     (Julia)

# %%
# 항목 집합의 항목 개수 추가하기
freq_items['length'] = freq_items['itemsets'].apply(lambda x: len(x))
freq_items
# Out:
#      support                            itemsets  length
# 0   0.030178                                (Go)       1
# 1   0.116598                              (Java)       1
# 2   0.231824                        (JavaScript)       1
# 3   0.053498                             (Julia)       1
# 4   0.056241                            (MATLAB)       1
# ..       ...                                 ...     ...
# 78  0.017833             (Julia, SQL, Python, R)       4
# 79  0.019204            (SQL, Python, R, MATLAB)       4
# 80  0.021948               (SQL, Python, R, SAS)       4
# 81  0.012346             (SQL, Python, R, Scala)       4
# 82  0.013717  (Python, R, Java, JavaScript, SQL)       5
#
# [83 rows x 3 columns]

# %%
# 신뢰도와 항상도 구하기
rules= association_rules(freq_items, min_threshold=0.01)
rules
# Out:
#       antecedents                      consequents  antecedent support  \
# 0            (Go)                     (JavaScript)            0.030178
# 1    (JavaScript)                             (Go)            0.231824
# 2            (Go)                         (Python)            0.030178
# 3        (Python)                             (Go)            0.855967
# 4            (Go)                            (SQL)            0.030178
# ..            ...                              ...                 ...
# 437      (Python)       (JavaScript, SQL, R, Java)            0.855967
# 438           (R)  (SQL, Python, JavaScript, Java)            0.292181
# 439        (Java)     (JavaScript, SQL, Python, R)            0.116598
# 440  (JavaScript)           (SQL, Python, R, Java)            0.231824
# 441         (SQL)    (JavaScript, Python, R, Java)            0.603567
#
#      consequent support   support  confidence      lift  representativity  \
# 0              0.231824  0.013717    0.454545  1.960732               1.0
# 1              0.030178  0.013717    0.059172  1.960732               1.0
# 2              0.855967  0.028807    0.954545  1.115166               1.0
# 3              0.030178  0.028807    0.033654  1.115166               1.0
# 4              0.603567  0.017833    0.590909  0.979029               1.0
# ..                  ...       ...         ...       ...               ...
# 437            0.013717  0.013717    0.016026  1.168269               1.0
# 438            0.043896  0.013717    0.046948  1.069542               1.0
# 439            0.048011  0.013717    0.117647  2.450420               1.0
# 440            0.016461  0.013717    0.059172  3.594675               1.0
# 441            0.013717  0.013717    0.022727  1.656818               1.0
#
#      leverage  conviction  zhangs_metric   jaccard  certainty  kulczynski
# 0    0.006721    1.408322       0.505233  0.055249   0.289935    0.256859
# 1    0.006721    1.030817       0.637857  0.055249   0.029895    0.256859
# 2    0.002975    3.168724       0.106486  0.033600   0.684416    0.494100
# 3    0.002975    1.003597       0.717007  0.033600   0.003584    0.494100
# 4   -0.000382    0.969060      -0.021610  0.028953  -0.031928    0.310227
# ..        ...         ...            ...       ...        ...         ...
# 437  0.001976    1.002346       1.000000  0.016026   0.002340    0.508013
# 438  0.000892    1.003203       0.091860  0.042553   0.003193    0.179724
# 439  0.008119    1.078921       0.670031  0.090909   0.073148    0.201681
# 440  0.009901    1.045397       0.939643  0.058480   0.043426    0.446252
# 441  0.005438    1.009219       1.000000  0.022727   0.009135    0.511364
#
# [442 rows x 14 columns]

# %%
# 산점도 그래프 그리기
fig=px.scatter(
    rules['support'],
    rules['confidence'],
    size=rules['lift'],
    color=rules['lift']
)

# 그래프 에리아웃 설정
fig.update_layout(
    xaxis_title='support',
    yaxis_title='confidence',
    font_family='Courier New',
    font_color='blue',
    title_font_family='Times New Roman',
    title_font_color='red',
    title=('Support vs Confidence')
)

# 그래프 출력
fig.show()

# %%
# frozenset 데이터를 문자열로 변환하여 열 추가
rules['antecedents_str'] = rules['antecedents'].apply(lambda x: ','.join(list(x)))
rules['consequents_str'] = rules['consequents'].apply(lambda x:','.join(list(x)))
rules
# Out:
#       antecedents                      consequents  antecedent support  \
# 0            (Go)                     (JavaScript)            0.030178
# 1    (JavaScript)                             (Go)            0.231824
# 2            (Go)                         (Python)            0.030178
# 3        (Python)                             (Go)            0.855967
# 4            (Go)                            (SQL)            0.030178
# ..            ...                              ...                 ...
# 437      (Python)       (JavaScript, SQL, R, Java)            0.855967
# 438           (R)  (SQL, Python, JavaScript, Java)            0.292181
# 439        (Java)     (JavaScript, SQL, Python, R)            0.116598
# 440  (JavaScript)           (SQL, Python, R, Java)            0.231824
# 441         (SQL)    (JavaScript, Python, R, Java)            0.603567
#
#      consequent support   support  confidence      lift  representativity  \
# 0              0.231824  0.013717    0.454545  1.960732               1.0
# 1              0.030178  0.013717    0.059172  1.960732               1.0
# 2              0.855967  0.028807    0.954545  1.115166               1.0
# 3              0.030178  0.028807    0.033654  1.115166               1.0
# 4              0.603567  0.017833    0.590909  0.979029               1.0
# ..                  ...       ...         ...       ...               ...
# 437            0.013717  0.013717    0.016026  1.168269               1.0
# 438            0.043896  0.013717    0.046948  1.069542               1.0
# 439            0.048011  0.013717    0.117647  2.450420               1.0
# 440            0.016461  0.013717    0.059172  3.594675               1.0
# 441            0.013717  0.013717    0.022727  1.656818               1.0
#
#      leverage  conviction  zhangs_metric   jaccard  certainty  kulczynski  \
# 0    0.006721    1.408322       0.505233  0.055249   0.289935    0.256859
# 1    0.006721    1.030817       0.637857  0.055249   0.029895    0.256859
# 2    0.002975    3.168724       0.106486  0.033600   0.684416    0.494100
# 3    0.002975    1.003597       0.717007  0.033600   0.003584    0.494100
# 4   -0.000382    0.969060      -0.021610  0.028953  -0.031928    0.310227
# ..        ...         ...            ...       ...        ...         ...
# 437  0.001976    1.002346       1.000000  0.016026   0.002340    0.508013
# 438  0.000892    1.003203       0.091860  0.042553   0.003193    0.179724
# 439  0.008119    1.078921       0.670031  0.090909   0.073148    0.201681
# 440  0.009901    1.045397       0.939643  0.058480   0.043426    0.446252
# 441  0.005438    1.009219       1.000000  0.022727   0.009135    0.511364
#
#     antecedents_str             consequents_str
# 0                Go                  JavaScript
# 1        JavaScript                          Go
# 2                Go                      Python
# 3            Python                          Go
# 4                Go                         SQL
# ..              ...                         ...
# 437          Python       JavaScript,SQL,R,Java
# 438               R  SQL,Python,JavaScript,Java
# 439            Java     JavaScript,SQL,Python,R
# 440      JavaScript           SQL,Python,R,Java
# 441             SQL    JavaScript,Python,R,Java
#
# [442 rows x 16 columns]

# %%
#산점도 그래프 그리기
fig=px.scatter(
    rules,
    x='support',
    y='confidence',
    size='lift',
    color='lift',
    hover_data=['antecedents_str','consequents_str']
)

#그래프 레이아웃 설정
fig.update_layout(
    xaxis_title='support',
    yaxis_title='confidence',
    font_family='Courier New',
    font_color='blue',
    title_font_family='Times New Roman',
    title_font_color='red',
    title=('Support vs Confidence')
)
#그래프 출력
fig.show()

# %% [markdown]
# ## 히트맵

# %%
# 항목이 하나인 값만 필터링하기
rules_for_single = rules[rules.apply(lambda x: (len(x['antecedents']) == 1 and len(x['consequents']) == 1), axis=1)]
rules_for_single
# Out:
#      antecedents   consequents  antecedent support  consequent support  \
# 0           (Go)  (JavaScript)            0.030178            0.231824
# 1   (JavaScript)          (Go)            0.231824            0.030178
# 2           (Go)      (Python)            0.030178            0.855967
# 3       (Python)          (Go)            0.855967            0.030178
# 4           (Go)         (SQL)            0.030178            0.603567
# 5          (SQL)          (Go)            0.603567            0.030178
# 6   (JavaScript)        (Java)            0.231824            0.116598
# 7         (Java)  (JavaScript)            0.116598            0.231824
# 8       (Python)        (Java)            0.855967            0.116598
# 9         (Java)      (Python)            0.116598            0.855967
# 10           (R)        (Java)            0.292181            0.116598
# 11        (Java)           (R)            0.116598            0.292181
# 12         (SQL)        (Java)            0.603567            0.116598
# 13        (Java)         (SQL)            0.116598            0.603567
# 14        (Java)       (Scala)            0.116598            0.039781
# 15       (Scala)        (Java)            0.039781            0.116598
# 16       (Julia)  (JavaScript)            0.053498            0.231824
# 17  (JavaScript)       (Julia)            0.231824            0.053498
# 18  (JavaScript)      (MATLAB)            0.231824            0.056241
# 19      (MATLAB)  (JavaScript)            0.056241            0.231824
# 20      (Python)  (JavaScript)            0.855967            0.231824
# 21  (JavaScript)      (Python)            0.231824            0.855967
# 22  (JavaScript)           (R)            0.231824            0.292181
# 23           (R)  (JavaScript)            0.292181            0.231824
# 24         (SQL)  (JavaScript)            0.603567            0.231824
# 25  (JavaScript)         (SQL)            0.231824            0.603567
# 26  (JavaScript)       (Scala)            0.231824            0.039781
# 27       (Scala)  (JavaScript)            0.039781            0.231824
# 28       (Julia)      (Python)            0.053498            0.855967
# 29      (Python)       (Julia)            0.855967            0.053498
# 30       (Julia)           (R)            0.053498            0.292181
# 31           (R)       (Julia)            0.292181            0.053498
# 32       (Julia)         (SQL)            0.053498            0.603567
# 33         (SQL)       (Julia)            0.603567            0.053498
# 34      (Python)      (MATLAB)            0.855967            0.056241
# 35      (MATLAB)      (Python)            0.056241            0.855967
# 36           (R)      (MATLAB)            0.292181            0.056241
# 37      (MATLAB)           (R)            0.056241            0.292181
# 38         (SQL)      (MATLAB)            0.603567            0.056241
# 39      (MATLAB)         (SQL)            0.056241            0.603567
# 40      (Python)           (R)            0.855967            0.292181
# 41           (R)      (Python)            0.292181            0.855967
# 42      (Python)         (SAS)            0.855967            0.045267
# 43         (SAS)      (Python)            0.045267            0.855967
# 44         (SQL)      (Python)            0.603567            0.855967
# 45      (Python)         (SQL)            0.855967            0.603567
# 46      (Python)       (Scala)            0.855967            0.039781
# 47       (Scala)      (Python)            0.039781            0.855967
# 48           (R)         (SAS)            0.292181            0.045267
# 49         (SAS)           (R)            0.045267            0.292181
# 50         (SQL)           (R)            0.603567            0.292181
# 51           (R)         (SQL)            0.292181            0.603567
# 52           (R)       (Scala)            0.292181            0.039781
# 53       (Scala)           (R)            0.039781            0.292181
# 54         (SQL)         (SAS)            0.603567            0.045267
# 55         (SAS)         (SQL)            0.045267            0.603567
# 56         (SQL)       (Scala)            0.603567            0.039781
# 57       (Scala)         (SQL)            0.039781            0.603567
#
#      support  confidence      lift  representativity  leverage  conviction  \
# 0   0.013717    0.454545  1.960732               1.0  0.006721    1.408322
# 1   0.013717    0.059172  1.960732               1.0  0.006721    1.030817
# 2   0.028807    0.954545  1.115166               1.0  0.002975    3.168724
# 3   0.028807    0.033654  1.115166               1.0  0.002975    1.003597
# 4   0.017833    0.590909  0.979029               1.0 -0.000382    0.969060
# 5   0.017833    0.029545  0.979029               1.0 -0.000382    0.999348
# 6   0.064472    0.278107  2.385172               1.0  0.037442    1.223729
# 7   0.064472    0.552941  2.385172               1.0  0.037442    1.718287
# 8   0.098765    0.115385  0.989593               1.0 -0.001039    0.998628
# 9   0.098765    0.847059  0.989593               1.0 -0.001039    0.941754
# 10  0.020576    0.070423  0.603977               1.0 -0.013492    0.950326
# 11  0.020576    0.176471  0.603977               1.0 -0.013492    0.859494
# 12  0.076818    0.127273  1.091551               1.0  0.006443    1.012231
# 13  0.076818    0.658824  1.091551               1.0  0.006443    1.161960
# 14  0.013717    0.117647  2.957404               1.0  0.009079    1.088249
# 15  0.013717    0.344828  2.957404               1.0  0.009079    1.348350
# 16  0.012346    0.230769  0.995448               1.0 -0.000056    0.998628
# 17  0.012346    0.053254  0.995448               1.0 -0.000056    0.999743
# 18  0.012346    0.053254  0.946890               1.0 -0.000692    0.996845
# 19  0.012346    0.219512  0.946890               1.0 -0.000692    0.984225
# 20  0.211248    0.246795  1.064577               1.0  0.012814    1.019876
# 21  0.211248    0.911243  1.064577               1.0  0.012814    1.622771
# 22  0.049383    0.213018  0.729061               1.0 -0.018352    0.899409
# 23  0.049383    0.169014  0.729061               1.0 -0.018352    0.924415
# 24  0.160494    0.265909  1.147028               1.0  0.020572    1.046431
# 25  0.160494    0.692308  1.147028               1.0  0.020572    1.288409
# 26  0.012346    0.053254  1.338706               1.0  0.003124    1.014232
# 27  0.012346    0.310345  1.338706               1.0  0.003124    1.113855
# 28  0.043896    0.820513  0.958580               1.0 -0.001897    0.802469
# 29  0.043896    0.051282  0.958580               1.0 -0.001897    0.997664
# 30  0.028807    0.538462  1.842904               1.0  0.013175    1.533608
# 31  0.028807    0.098592  1.842904               1.0  0.013175    1.050026
# 32  0.028807    0.538462  0.892133               1.0 -0.003483    0.858939
# 33  0.028807    0.047727  0.892133               1.0 -0.003483    0.993940
# 34  0.056241    0.065705  1.168269               1.0  0.008101    1.010129
# 35  0.056241    1.000000  1.168269               1.0  0.008101         inf
# 36  0.023320    0.079812  1.419100               1.0  0.006887    1.025615
# 37  0.023320    0.414634  1.419100               1.0  0.006887    1.209191
# 38  0.041152    0.068182  1.212306               1.0  0.007207    1.012814
# 39  0.041152    0.731707  1.212306               1.0  0.007207    1.477616
# 40  0.237311    0.277244  0.948876               1.0 -0.012786    0.979333
# 41  0.237311    0.812207  0.948876               1.0 -0.012786    0.766975
# 42  0.037037    0.043269  0.955857               1.0 -0.001710    0.997911
# 43  0.037037    0.818182  0.955857               1.0 -0.001710    0.792181
# 44  0.517147    0.856818  1.000994               1.0  0.000514    1.005944
# 45  0.517147    0.604167  1.000994               1.0  0.000514    1.001516
# 46  0.038409    0.044872  1.127984               1.0  0.004358    1.005330
# 47  0.038409    0.965517  1.127984               1.0  0.004358    4.176955
# 48  0.028807    0.098592  2.177977               1.0  0.015580    1.059156
# 49  0.028807    0.636364  2.177977               1.0  0.015580    1.946502
# 50  0.213992    0.354545  1.213444               1.0  0.037641    1.096621
# 51  0.213992    0.732394  1.213444               1.0  0.037641    1.481409
# 52  0.019204    0.065728  1.652258               1.0  0.007581    1.027773
# 53  0.019204    0.482759  1.652258               1.0  0.007581    1.368450
# 54  0.043896    0.072727  1.606612               1.0  0.016574    1.029613
# 55  0.043896    0.969697  1.606612               1.0  0.016574   13.082305
# 56  0.028807    0.047727  1.199765               1.0  0.004796    1.008345
# 57  0.028807    0.724138  1.199765               1.0  0.004796    1.437071
#
#     zhangs_metric   jaccard  certainty  kulczynski antecedents_str  \
# 0        0.505233  0.055249   0.289935    0.256859              Go
# 1        0.637857  0.055249   0.029895    0.256859      JavaScript
# 2        0.106486  0.033600   0.684416    0.494100              Go
# 3        0.717007  0.033600   0.003584    0.494100          Python
# 4       -0.021610  0.028953  -0.031928    0.310227              Go
# 5       -0.051263  0.028953  -0.000653    0.310227             SQL
# 6        0.756003  0.227053   0.182826    0.415524      JavaScript
# 7        0.657394  0.227053   0.418025    0.415524            Java
# 8       -0.068047  0.113030  -0.001374    0.481222          Python
# 9       -0.011765  0.113030  -0.061849    0.481222            Java
# 10      -0.480885  0.053004  -0.052270    0.123447               R
# 11      -0.426025  0.053004  -0.163475    0.123447            Java
# 12       0.211567  0.119403   0.012084    0.393048             SQL
# 13       0.094942  0.119403   0.139385    0.393048            Java
# 14       0.749224  0.096154   0.081092    0.231237            Java
# 15       0.689286  0.096154   0.258353    0.231237           Scala
# 16      -0.004808  0.045226  -0.001374    0.142012           Julia
# 17      -0.005917  0.045226  -0.000257    0.142012      JavaScript
# 18      -0.068047  0.044776  -0.003165    0.136383      JavaScript
# 19      -0.056098  0.044776  -0.016028    0.136383          MATLAB
# 20       0.421150  0.241002   0.019488    0.579019          Python
# 21       0.078966  0.241002   0.383770    0.579019      JavaScript
# 22      -0.326046  0.104046  -0.111841    0.191016      JavaScript
# 23      -0.344276  0.104046  -0.081766    0.191016               R
# 24       0.323337  0.237805   0.044371    0.479108             SQL
# 25       0.166865  0.237805   0.223849    0.479108      JavaScript
# 26       0.329365  0.047619   0.014032    0.181800      JavaScript
# 27       0.263492  0.047619   0.102217    0.181800           Scala
# 28      -0.043659  0.050713  -0.246154    0.435897           Julia
# 29      -0.230769  0.050713  -0.002341    0.435897          Python
# 30       0.483230  0.090909   0.347943    0.318527           Julia
# 31       0.646179  0.090909   0.047642    0.318527               R
# 32      -0.113273  0.045852  -0.164227    0.293094           Julia
# 33      -0.233712  0.045852  -0.006097    0.293094             SQL
# 34       1.000000  0.065705   0.010028    0.532853          Python
# 35       0.152616  0.065705   1.000000    0.532853          MATLAB
# 36       0.417237  0.071730   0.024975    0.247223               R
# 37       0.312927  0.071730   0.173001    0.247223          MATLAB
# 38       0.441753  0.066519   0.012652    0.399945             SQL
# 39       0.185562  0.066519   0.323234    0.399945          MATLAB
# 40      -0.272236  0.260542  -0.021104    0.544725          Python
# 41      -0.070735  0.260542  -0.303823    0.544725               R
# 42      -0.242788  0.042857  -0.002093    0.430726          Python
# 43      -0.046140  0.042857  -0.262338    0.430726             SAS
# 44       0.002506  0.548763   0.005909    0.730492             SQL
# 45       0.006897  0.548763   0.001514    0.730492          Python
# 46       0.787755  0.044800   0.005302    0.505195          Python
# 47       0.118163  0.044800   0.760591    0.505195           Scala
# 48       0.764120  0.093333   0.055852    0.367478               R
# 49       0.566502  0.093333   0.486258    0.367478             SAS
# 50       0.443705  0.313883   0.088108    0.543470             SQL
# 51       0.248509  0.313883   0.324967    0.543470               R
# 52       0.557724  0.061404   0.027022    0.274243               R
# 53       0.411122  0.061404   0.269246    0.274243           Scala
# 54       0.952422  0.072562   0.028762    0.521212             SQL
# 55       0.395474  0.072562   0.923561    0.521212             SAS
# 56       0.420003  0.046875   0.008276    0.385933             SQL
# 57       0.173401  0.046875   0.304140    0.385933           Scala
#
#    consequents_str
# 0       JavaScript
# 1               Go
# 2           Python
# 3               Go
# 4              SQL
# 5               Go
# 6             Java
# 7       JavaScript
# 8             Java
# 9           Python
# 10            Java
# 11               R
# 12            Java
# 13             SQL
# 14           Scala
# 15            Java
# 16      JavaScript
# 17           Julia
# 18          MATLAB
# 19      JavaScript
# 20      JavaScript
# 21          Python
# 22               R
# 23      JavaScript
# 24      JavaScript
# 25             SQL
# 26           Scala
# 27      JavaScript
# 28          Python
# 29           Julia
# 30               R
# 31           Julia
# 32             SQL
# 33           Julia
# 34          MATLAB
# 35          Python
# 36          MATLAB
# 37               R
# 38          MATLAB
# 39             SQL
# 40               R
# 41          Python
# 42             SAS
# 43          Python
# 44          Python
# 45             SQL
# 46           Scala
# 47          Python
# 48             SAS
# 49               R
# 50               R
# 51             SQL
# 52           Scala
# 53               R
# 54             SAS
# 55             SQL
# 56           Scala
# 57             SQL

# %%
# 프로그래밍 언어 문자열로 추출
# 프로그래밍 언어 문자열로 추출
rules_for_single_df = pd.DataFrame(rules_for_single['antecedents'].apply(lambda x: list(x)[0]))

rules_for_single_df['consequents'] = (rules_for_single['consequents'].apply(lambda x: list(x)[0]))

rules_for_single_df['confidence'] = rules_for_single['confidence']

rules_for_single_df
# Out:
#    antecedents consequents  confidence
# 0           Go  JavaScript    0.454545
# 1   JavaScript          Go    0.059172
# 2           Go      Python    0.954545
# 3       Python          Go    0.033654
# 4           Go         SQL    0.590909
# 5          SQL          Go    0.029545
# 6   JavaScript        Java    0.278107
# 7         Java  JavaScript    0.552941
# 8       Python        Java    0.115385
# 9         Java      Python    0.847059
# 10           R        Java    0.070423
# 11        Java           R    0.176471
# 12         SQL        Java    0.127273
# 13        Java         SQL    0.658824
# 14        Java       Scala    0.117647
# 15       Scala        Java    0.344828
# 16       Julia  JavaScript    0.230769
# 17  JavaScript       Julia    0.053254
# 18  JavaScript      MATLAB    0.053254
# 19      MATLAB  JavaScript    0.219512
# 20      Python  JavaScript    0.246795
# 21  JavaScript      Python    0.911243
# 22  JavaScript           R    0.213018
# 23           R  JavaScript    0.169014
# 24         SQL  JavaScript    0.265909
# 25  JavaScript         SQL    0.692308
# 26  JavaScript       Scala    0.053254
# 27       Scala  JavaScript    0.310345
# 28       Julia      Python    0.820513
# 29      Python       Julia    0.051282
# 30       Julia           R    0.538462
# 31           R       Julia    0.098592
# 32       Julia         SQL    0.538462
# 33         SQL       Julia    0.047727
# 34      Python      MATLAB    0.065705
# 35      MATLAB      Python    1.000000
# 36           R      MATLAB    0.079812
# 37      MATLAB           R    0.414634
# 38         SQL      MATLAB    0.068182
# 39      MATLAB         SQL    0.731707
# 40      Python           R    0.277244
# 41           R      Python    0.812207
# 42      Python         SAS    0.043269
# 43         SAS      Python    0.818182
# 44         SQL      Python    0.856818
# 45      Python         SQL    0.604167
# 46      Python       Scala    0.044872
# 47       Scala      Python    0.965517
# 48           R         SAS    0.098592
# 49         SAS           R    0.636364
# 50         SQL           R    0.354545
# 51           R         SQL    0.732394
# 52           R       Scala    0.065728
# 53       Scala           R    0.482759
# 54         SQL         SAS    0.072727
# 55         SAS         SQL    0.969697
# 56         SQL       Scala    0.047727
# 57       Scala         SQL    0.724138

# %%
# 히트맵용 데이터프레임 생성, 색상은 대상 프로그래밍 언어로 설정
revised_rules_df = pd.DataFrame(index=target_langs)

# 대상 프로그래밍 언어 순회
for col in target_langs:
    # 열 설정을 위한 빈 리스트 생성
    col_conf=[]
    for row in target_langs:
        confidence = rules_for_single_df[rules_for_single_df['antecedents'] == row][rules_for_single_df['consequents'] == col]['confidence']

        if len(confidence.values) > 0:
            col_conf.append(confidence.values[0])

        else:
            col_conf.append(0)

    # 완성된 열을 데이터프레임에 추가
    revised_rules_df[col] = col_conf

# 최종 데이터프레임 값 확인
revised_rules_df
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_1136\3876731635.py:9: UserWarning:
#
# Boolean Series key will be reindexed to match DataFrame index.
#
# C:\Users\USER\AppData\Local\Temp\ipykernel_1136\3876731635.py:9: UserWarning:
#
# Boolean Series key will be reindexed to match DataFrame index.
#
# C:\Users\USER\AppData\Local\Temp\ipykernel_1136\3876731635.py:9: UserWarning:
#
# Boolean Series key will be reindexed to match DataFrame index.
#
# C:\Users\USER\AppData\Local\Temp\ipykernel_1136\3876731635.py:9: UserWarning:
#
# Boolean Series key will be reindexed to match DataFrame index.
#
# C:\Users\USER\AppData\Local\Temp\ipykernel_1136\3876731635.py:9: UserWarning:
#
# Boolean Series key will be reindexed to match DataFrame index.
#
# C:\Users\USER\AppData\Local\Temp\ipykernel_1136\3876731635.py:9: UserWarning:
#
# Boolean Series key will be reindexed to match DataFrame index.
#
# C:\Users\USER\AppData\Local\Temp\ipykernel_1136\3876731635.py:9: UserWarning:
#
# Boolean Series key will be reindexed to match DataFrame index.
#
# C:\Users\USER\AppData\Local\Temp\ipykernel_1136\3876731635.py:9: UserWarning:
#
# Boolean Series key will be reindexed to match DataFrame index.
#
# C:\Users\USER\AppData\Local\Temp\ipykernel_1136\3876731635.py:9: UserWarning:
#
# Boolean Series key will be reindexed to match DataFrame index.
#
# C:\Users\USER\AppData\Local\Temp\ipykernel_1136\3876731635.py:9: UserWarning:
#
# Boolean Series key will be reindexed to match DataFrame index.
#
# C:\Users\USER\AppData\Local\Temp\ipykernel_1136\3876731635.py:9: UserWarning:
#
# Boolean Series key will be reindexed to match DataFrame index.
#
# C:\Users\USER\AppData\Local\Temp\ipykernel_1136\3876731635.py:9: UserWarning:
#
# Boolean Series key will be reindexed to match DataFrame index.
#
# C:\Users\USER\AppData\Local\Temp\ipykernel_1136\3876731635.py:9: UserWarning:
#
# Boolean Series key will be reindexed to match DataFrame index.
#
# C:\Users\USER\AppData\Local\Temp\ipykernel_1136\3876731635.py:9: UserWarning:
#
# Boolean Series key will be reindexed to match DataFrame index.
#
# C:\Users\USER\AppData\Local\Temp\ipykernel_1136\3876731635.py:9: UserWarning:
#
# Boolean Series key will be reindexed to match DataFrame index.
#
# C:\Users\USER\AppData\Local\Temp\ipykernel_1136\3876731635.py:9: UserWarning:
#
# Boolean Series key will be reindexed to match DataFrame index.
#
# C:\Users\USER\AppData\Local\Temp\ipykernel_1136\3876731635.py:9: UserWarning:
#
# Boolean Series key will be reindexed to match DataFrame index.
#
# C:\Users\USER\AppData\Local\Temp\ipykernel_1136\3876731635.py:9: UserWarning:
#
# Boolean Series key will be reindexed to match DataFrame index.
#
# C:\Users\USER\AppData\Local\Temp\ipykernel_1136\3876731635.py:9: UserWarning:
#
# Boolean Series key will be reindexed to match DataFrame index.
#
# C:\Users\USER\AppData\Local\Temp\ipykernel_1136\3876731635.py:9: UserWarning:
#
# Boolean Series key will be reindexed to match DataFrame index.
#
# C:\Users\USER\AppData\Local\Temp\ipykernel_1136\3876731635.py:9: UserWarning:
#
# Boolean Series key will be reindexed to match DataFrame index.
#
# C:\Users\USER\AppData\Local\Temp\ipykernel_1136\3876731635.py:9: UserWarning:
#
# Boolean Series key will be reindexed to match DataFrame index.
#
# C:\Users\USER\AppData\Local\Temp\ipykernel_1136\3876731635.py:9: UserWarning:
#
# Boolean Series key will be reindexed to match DataFrame index.
#
# C:\Users\USER\AppData\Local\Temp\ipykernel_1136\3876731635.py:9: UserWarning:
#
# Boolean Series key will be reindexed to match DataFrame index.
#
# C:\Users\USER\AppData\Local\Temp\ipykernel_1136\3876731635.py:9: UserWarning:
#
# Boolean Series key will be reindexed to match DataFrame index.
#
# C:\Users\USER\AppData\Local\Temp\ipykernel_1136\3876731635.py:9: UserWarning:
#
# Boolean Series key will be reindexed to match DataFrame index.
#
# C:\Users\USER\AppData\Local\Temp\ipykernel_1136\3876731635.py:9: UserWarning:
#
# Boolean Series key will be reindexed to match DataFrame index.
#
# C:\Users\USER\AppData\Local\Temp\ipykernel_1136\3876731635.py:9: UserWarning:
#
# Boolean Series key will be reindexed to match DataFrame index.
#
# C:\Users\USER\AppData\Local\Temp\ipykernel_1136\3876731635.py:9: UserWarning:
#
# Boolean Series key will be reindexed to match DataFrame index.
#
# C:\Users\USER\AppData\Local\Temp\ipykernel_1136\3876731635.py:9: UserWarning:
#
# Boolean Series key will be reindexed to match DataFrame index.
#
# C:\Users\USER\AppData\Local\Temp\ipykernel_1136\3876731635.py:9: UserWarning:
#
# Boolean Series key will be reindexed to match DataFrame index.
#
# C:\Users\USER\AppData\Local\Temp\ipykernel_1136\3876731635.py:9: UserWarning:
#
# Boolean Series key will be reindexed to match DataFrame index.
#
# C:\Users\USER\AppData\Local\Temp\ipykernel_1136\3876731635.py:9: UserWarning:
#
# Boolean Series key will be reindexed to match DataFrame index.
#
# C:\Users\USER\AppData\Local\Temp\ipykernel_1136\3876731635.py:9: UserWarning:
#
# Boolean Series key will be reindexed to match DataFrame index.
#
# C:\Users\USER\AppData\Local\Temp\ipykernel_1136\3876731635.py:9: UserWarning:
#
# Boolean Series key will be reindexed to match DataFrame index.
#
# C:\Users\USER\AppData\Local\Temp\ipykernel_1136\3876731635.py:9: UserWarning:
#
# Boolean Series key will be reindexed to match DataFrame index.
#
# C:\Users\USER\AppData\Local\Temp\ipykernel_1136\3876731635.py:9: UserWarning:
#
# Boolean Series key will be reindexed to match DataFrame index.
#
# C:\Users\USER\AppData\Local\Temp\ipykernel_1136\3876731635.py:9: UserWarning:
#
# Boolean Series key will be reindexed to match DataFrame index.
#
# C:\Users\USER\AppData\Local\Temp\ipykernel_1136\3876731635.py:9: UserWarning:
#
# Boolean Series key will be reindexed to match DataFrame index.
#
# C:\Users\USER\AppData\Local\Temp\ipykernel_1136\3876731635.py:9: UserWarning:
#
# Boolean Series key will be reindexed to match DataFrame index.
#
# C:\Users\USER\AppData\Local\Temp\ipykernel_1136\3876731635.py:9: UserWarning:
#
# Boolean Series key will be reindexed to match DataFrame index.
#
# C:\Users\USER\AppData\Local\Temp\ipykernel_1136\3876731635.py:9: UserWarning:
#
# Boolean Series key will be reindexed to match DataFrame index.
#
# C:\Users\USER\AppData\Local\Temp\ipykernel_1136\3876731635.py:9: UserWarning:
#
# Boolean Series key will be reindexed to match DataFrame index.
#
# C:\Users\USER\AppData\Local\Temp\ipykernel_1136\3876731635.py:9: UserWarning:
#
# Boolean Series key will be reindexed to match DataFrame index.
#
# C:\Users\USER\AppData\Local\Temp\ipykernel_1136\3876731635.py:9: UserWarning:
#
# Boolean Series key will be reindexed to match DataFrame index.
#
# C:\Users\USER\AppData\Local\Temp\ipykernel_1136\3876731635.py:9: UserWarning:
#
# Boolean Series key will be reindexed to match DataFrame index.
#
# C:\Users\USER\AppData\Local\Temp\ipykernel_1136\3876731635.py:9: UserWarning:
#
# Boolean Series key will be reindexed to match DataFrame index.
#
# C:\Users\USER\AppData\Local\Temp\ipykernel_1136\3876731635.py:9: UserWarning:
#
# Boolean Series key will be reindexed to match DataFrame index.
#
# C:\Users\USER\AppData\Local\Temp\ipykernel_1136\3876731635.py:9: UserWarning:
#
# Boolean Series key will be reindexed to match DataFrame index.
#
# C:\Users\USER\AppData\Local\Temp\ipykernel_1136\3876731635.py:9: UserWarning:
#
# Boolean Series key will be reindexed to match DataFrame index.
#
# C:\Users\USER\AppData\Local\Temp\ipykernel_1136\3876731635.py:9: UserWarning:
#
# Boolean Series key will be reindexed to match DataFrame index.
#
# C:\Users\USER\AppData\Local\Temp\ipykernel_1136\3876731635.py:9: UserWarning:
#
# Boolean Series key will be reindexed to match DataFrame index.
#
# C:\Users\USER\AppData\Local\Temp\ipykernel_1136\3876731635.py:9: UserWarning:
#
# Boolean Series key will be reindexed to match DataFrame index.
#
# C:\Users\USER\AppData\Local\Temp\ipykernel_1136\3876731635.py:9: UserWarning:
#
# Boolean Series key will be reindexed to match DataFrame index.
#
# C:\Users\USER\AppData\Local\Temp\ipykernel_1136\3876731635.py:9: UserWarning:
#
# Boolean Series key will be reindexed to match DataFrame index.
#
# C:\Users\USER\AppData\Local\Temp\ipykernel_1136\3876731635.py:9: UserWarning:
#
# Boolean Series key will be reindexed to match DataFrame index.
#
# C:\Users\USER\AppData\Local\Temp\ipykernel_1136\3876731635.py:9: UserWarning:
#
# Boolean Series key will be reindexed to match DataFrame index.
#
# C:\Users\USER\AppData\Local\Temp\ipykernel_1136\3876731635.py:9: UserWarning:
#
# Boolean Series key will be reindexed to match DataFrame index.
#
# C:\Users\USER\AppData\Local\Temp\ipykernel_1136\3876731635.py:9: UserWarning:
#
# Boolean Series key will be reindexed to match DataFrame index.
#
# C:\Users\USER\AppData\Local\Temp\ipykernel_1136\3876731635.py:9: UserWarning:
#
# Boolean Series key will be reindexed to match DataFrame index.
#
# C:\Users\USER\AppData\Local\Temp\ipykernel_1136\3876731635.py:9: UserWarning:
#
# Boolean Series key will be reindexed to match DataFrame index.
#
# C:\Users\USER\AppData\Local\Temp\ipykernel_1136\3876731635.py:9: UserWarning:
#
# Boolean Series key will be reindexed to match DataFrame index.
#
# C:\Users\USER\AppData\Local\Temp\ipykernel_1136\3876731635.py:9: UserWarning:
#
# Boolean Series key will be reindexed to match DataFrame index.
#
# C:\Users\USER\AppData\Local\Temp\ipykernel_1136\3876731635.py:9: UserWarning:
#
# Boolean Series key will be reindexed to match DataFrame index.
#
# C:\Users\USER\AppData\Local\Temp\ipykernel_1136\3876731635.py:9: UserWarning:
#
# Boolean Series key will be reindexed to match DataFrame index.
#
# C:\Users\USER\AppData\Local\Temp\ipykernel_1136\3876731635.py:9: UserWarning:
#
# Boolean Series key will be reindexed to match DataFrame index.
#
# C:\Users\USER\AppData\Local\Temp\ipykernel_1136\3876731635.py:9: UserWarning:
#
# Boolean Series key will be reindexed to match DataFrame index.
#
# C:\Users\USER\AppData\Local\Temp\ipykernel_1136\3876731635.py:9: UserWarning:
#
# Boolean Series key will be reindexed to match DataFrame index.
#
# C:\Users\USER\AppData\Local\Temp\ipykernel_1136\3876731635.py:9: UserWarning:
#
# Boolean Series key will be reindexed to match DataFrame index.
#
# C:\Users\USER\AppData\Local\Temp\ipykernel_1136\3876731635.py:9: UserWarning:
#
# Boolean Series key will be reindexed to match DataFrame index.
#
# C:\Users\USER\AppData\Local\Temp\ipykernel_1136\3876731635.py:9: UserWarning:
#
# Boolean Series key will be reindexed to match DataFrame index.
#
# C:\Users\USER\AppData\Local\Temp\ipykernel_1136\3876731635.py:9: UserWarning:
#
# Boolean Series key will be reindexed to match DataFrame index.
#
# C:\Users\USER\AppData\Local\Temp\ipykernel_1136\3876731635.py:9: UserWarning:
#
# Boolean Series key will be reindexed to match DataFrame index.
#
# C:\Users\USER\AppData\Local\Temp\ipykernel_1136\3876731635.py:9: UserWarning:
#
# Boolean Series key will be reindexed to match DataFrame index.
#
# C:\Users\USER\AppData\Local\Temp\ipykernel_1136\3876731635.py:9: UserWarning:
#
# Boolean Series key will be reindexed to match DataFrame index.
#
# C:\Users\USER\AppData\Local\Temp\ipykernel_1136\3876731635.py:9: UserWarning:
#
# Boolean Series key will be reindexed to match DataFrame index.
#
# C:\Users\USER\AppData\Local\Temp\ipykernel_1136\3876731635.py:9: UserWarning:
#
# Boolean Series key will be reindexed to match DataFrame index.
#
# C:\Users\USER\AppData\Local\Temp\ipykernel_1136\3876731635.py:9: UserWarning:
#
# Boolean Series key will be reindexed to match DataFrame index.
#
# C:\Users\USER\AppData\Local\Temp\ipykernel_1136\3876731635.py:9: UserWarning:
#
# Boolean Series key will be reindexed to match DataFrame index.
#
# C:\Users\USER\AppData\Local\Temp\ipykernel_1136\3876731635.py:9: UserWarning:
#
# Boolean Series key will be reindexed to match DataFrame index.
#
# C:\Users\USER\AppData\Local\Temp\ipykernel_1136\3876731635.py:9: UserWarning:
#
# Boolean Series key will be reindexed to match DataFrame index.
#
# C:\Users\USER\AppData\Local\Temp\ipykernel_1136\3876731635.py:9: UserWarning:
#
# Boolean Series key will be reindexed to match DataFrame index.
#
# C:\Users\USER\AppData\Local\Temp\ipykernel_1136\3876731635.py:9: UserWarning:
#
# Boolean Series key will be reindexed to match DataFrame index.
#
# C:\Users\USER\AppData\Local\Temp\ipykernel_1136\3876731635.py:9: UserWarning:
#
# Boolean Series key will be reindexed to match DataFrame index.
#
# C:\Users\USER\AppData\Local\Temp\ipykernel_1136\3876731635.py:9: UserWarning:
#
# Boolean Series key will be reindexed to match DataFrame index.
#
# C:\Users\USER\AppData\Local\Temp\ipykernel_1136\3876731635.py:9: UserWarning:
#
# Boolean Series key will be reindexed to match DataFrame index.
#
# C:\Users\USER\AppData\Local\Temp\ipykernel_1136\3876731635.py:9: UserWarning:
#
# Boolean Series key will be reindexed to match DataFrame index.
#
# C:\Users\USER\AppData\Local\Temp\ipykernel_1136\3876731635.py:9: UserWarning:
#
# Boolean Series key will be reindexed to match DataFrame index.
#
# C:\Users\USER\AppData\Local\Temp\ipykernel_1136\3876731635.py:9: UserWarning:
#
# Boolean Series key will be reindexed to match DataFrame index.
#
# C:\Users\USER\AppData\Local\Temp\ipykernel_1136\3876731635.py:9: UserWarning:
#
# Boolean Series key will be reindexed to match DataFrame index.
#
# C:\Users\USER\AppData\Local\Temp\ipykernel_1136\3876731635.py:9: UserWarning:
#
# Boolean Series key will be reindexed to match DataFrame index.
#
# C:\Users\USER\AppData\Local\Temp\ipykernel_1136\3876731635.py:9: UserWarning:
#
# Boolean Series key will be reindexed to match DataFrame index.
#
# C:\Users\USER\AppData\Local\Temp\ipykernel_1136\3876731635.py:9: UserWarning:
#
# Boolean Series key will be reindexed to match DataFrame index.
#
# C:\Users\USER\AppData\Local\Temp\ipykernel_1136\3876731635.py:9: UserWarning:
#
# Boolean Series key will be reindexed to match DataFrame index.
#
# C:\Users\USER\AppData\Local\Temp\ipykernel_1136\3876731635.py:9: UserWarning:
#
# Boolean Series key will be reindexed to match DataFrame index.
#
# C:\Users\USER\AppData\Local\Temp\ipykernel_1136\3876731635.py:9: UserWarning:
#
# Boolean Series key will be reindexed to match DataFrame index.
#
# C:\Users\USER\AppData\Local\Temp\ipykernel_1136\3876731635.py:9: UserWarning:
#
# Boolean Series key will be reindexed to match DataFrame index.
#
# C:\Users\USER\AppData\Local\Temp\ipykernel_1136\3876731635.py:9: UserWarning:
#
# Boolean Series key will be reindexed to match DataFrame index.
#
# C:\Users\USER\AppData\Local\Temp\ipykernel_1136\3876731635.py:9: UserWarning:
#
# Boolean Series key will be reindexed to match DataFrame index.
#
# C:\Users\USER\AppData\Local\Temp\ipykernel_1136\3876731635.py:9: UserWarning:
#
# Boolean Series key will be reindexed to match DataFrame index.
#               Python         R       SQL    MATLAB        Go       SAS  \
# Python      0.000000  0.277244  0.604167  0.065705  0.033654  0.043269
# R           0.812207  0.000000  0.732394  0.079812  0.000000  0.098592
# SQL         0.856818  0.354545  0.000000  0.068182  0.029545  0.072727
# MATLAB      1.000000  0.414634  0.731707  0.000000  0.000000  0.000000
# Go          0.954545  0.000000  0.590909  0.000000  0.000000  0.000000
# SAS         0.818182  0.636364  0.969697  0.000000  0.000000  0.000000
# Scala       0.965517  0.482759  0.724138  0.000000  0.000000  0.000000
# Julia       0.820513  0.538462  0.538462  0.000000  0.000000  0.000000
# Java        0.847059  0.176471  0.658824  0.000000  0.000000  0.000000
# JavaScript  0.911243  0.213018  0.692308  0.053254  0.059172  0.000000
#
#                Scala     Julia      Java  JavaScript
# Python      0.044872  0.051282  0.115385    0.246795
# R           0.065728  0.098592  0.070423    0.169014
# SQL         0.047727  0.047727  0.127273    0.265909
# MATLAB      0.000000  0.000000  0.000000    0.219512
# Go          0.000000  0.000000  0.000000    0.454545
# SAS         0.000000  0.000000  0.000000    0.000000
# Scala       0.000000  0.000000  0.344828    0.310345
# Julia       0.000000  0.000000  0.000000    0.230769
# Java        0.117647  0.000000  0.000000    0.552941
# JavaScript  0.053254  0.053254  0.278107    0.000000

# %%
# Seaborn 라이브러리 탑재
import seaborn as sns

# 히트맵 크기 설정
plt.figure(figsize=(15, 5))

# 히트맵 그리기
heatmap = sns.heatmap(revised_rules_df, annot=True)

# %%
target_langs = ['Python', 'R', 'SQL','MATLAB', 'Go', 'SAS', 'Scala', 'Julia', 'Java', 'JavaScript']

# %%
revised_lang_list = []
for lang in lang_list:
    filtered = [x for x in lang if x in target_langs]
    revised_lang_list.append(filtered)

revised_lang_list
# Out:
# [['Python', 'SQL'],
#  ['Python', 'SQL'],
#  ['Python', 'SQL'],
#  ['Python'],
#  ['Python', 'SQL'],
#  ['Python'],
#  ['JavaScript', 'Python', 'SQL'],
#  ['Python', 'SQL'],
#  ['Go', 'Python'],
#  ['Python'],
#  ['Python'],
#  ['Go', 'Java'],
#  ['JavaScript', 'Python'],
#  ['Python', 'R', 'SQL'],
#  ['Julia', 'Python', 'R'],
#  ['Python', 'SQL'],
#  ['JavaScript', 'Python'],
#  ['Python', 'SQL'],
#  ['Julia', 'Python', 'R', 'SQL'],
#  ['Python'],
#  ['Python', 'R', 'SAS', 'SQL'],
#  ['Python'],
#  ['JavaScript', 'Python', 'SQL'],
#  ['JavaScript', 'Python', 'R', 'SAS', 'SQL'],
#  ['Python', 'Scala', 'SQL'],
#  ['Python', 'R'],
#  ['Python', 'R'],
#  ['JavaScript', 'Python', 'R', 'SQL'],
#  ['Python'],
#  ['Python'],
#  ['Python', 'R', 'SQL'],
#  ['JavaScript', 'Python'],
#  ['SQL'],
#  ['Python', 'R', 'SQL'],
#  ['Python', 'SQL'],
#  ['Python'],
#  ['Python', 'R', 'SQL'],
#  ['Python'],
#  ['Python'],
#  ['Julia', 'Python', 'R', 'SQL'],
#  ['Java', 'Python'],
#  ['Python'],
#  ['Python'],
#  ['JavaScript', 'Python', 'SQL'],
#  ['Java', 'JavaScript', 'Python'],
#  ['JavaScript', 'Python'],
#  ['Python', 'SQL'],
#  ['MATLAB', 'Python', 'R'],
#  ['Java', 'JavaScript', 'Python', 'SQL'],
#  ['MATLAB', 'Python', 'R', 'SQL'],
#  ['Python', 'SQL'],
#  ['Julia', 'Python', 'SQL'],
#  ['Python'],
#  ['Python'],
#  ['Python', 'SQL'],
#  ['Python'],
#  ['Python', 'SQL'],
#  ['Python', 'R', 'SQL'],
#  ['SQL'],
#  ['Python'],
#  ['Java', 'JavaScript', 'SQL'],
#  ['Python', 'SQL'],
#  ['Python', 'R', 'Scala', 'SQL'],
#  ['Python', 'R'],
#  ['Python'],
#  ['JavaScript', 'Python', 'SQL'],
#  ['Python', 'R', 'SQL'],
#  ['R'],
#  [],
#  ['Go', 'Python', 'SAS', 'SQL'],
#  ['Go', 'JavaScript', 'Python', 'SQL'],
#  ['Java', 'JavaScript', 'Python', 'SQL'],
#  ['Java', 'JavaScript', 'Python', 'R', 'SQL'],
#  ['Python', 'SQL'],
#  ['Python', 'R', 'SQL'],
#  ['JavaScript', 'SQL'],
#  ['Python'],
#  [],
#  ['Python'],
#  ['Python'],
#  ['Java', 'JavaScript', 'MATLAB', 'Python', 'SQL'],
#  ['JavaScript', 'Python', 'SQL'],
#  ['JavaScript', 'Python'],
#  ['Python', 'R', 'SQL'],
#  ['Python'],
#  ['Python'],
#  ['JavaScript', 'Python', 'SQL'],
#  ['Python', 'SQL'],
#  ['Java', 'JavaScript', 'Python', 'R', 'SQL'],
#  ['Python', 'Scala', 'SQL'],
#  ['Python', 'R'],
#  ['Go', 'JavaScript', 'Python'],
#  ['Python', 'R'],
#  ['Python', 'R', 'SAS', 'Scala', 'SQL'],
#  ['JavaScript', 'Python'],
#  ['MATLAB', 'Python'],
#  ['Python'],
#  ['Java', 'JavaScript', 'Python'],
#  ['Python', 'R', 'SQL'],
#  ['Python'],
#  ['R'],
#  ['Julia', 'SQL'],
#  ['Python'],
#  ['JavaScript', 'Python', 'SQL'],
#  ['Python', 'SQL'],
#  ['Python'],
#  ['Python', 'SQL'],
#  ['JavaScript', 'Julia', 'Python'],
#  ['JavaScript', 'Python', 'SQL'],
#  ['Python', 'R'],
#  ['Python', 'SQL'],
#  ['Python'],
#  ['Python', 'SQL'],
#  ['Python'],
#  ['Python', 'R'],
#  ['Python'],
#  ['JavaScript', 'Python'],
#  ['Java', 'MATLAB', 'Python', 'SAS', 'SQL'],
#  ['Julia', 'Python'],
#  ['R', 'SAS', 'SQL'],
#  ['Python', 'R', 'SQL'],
#  ['Python', 'R'],
#  ['JavaScript', 'Python', 'R', 'SQL'],
#  ['Julia', 'Python', 'R', 'SQL'],
#  ['MATLAB', 'Python', 'SQL'],
#  ['Python', 'SQL'],
#  ['Python', 'R'],
#  ['Java', 'JavaScript', 'Python', 'SAS', 'SQL'],
#  [],
#  ['Python', 'SAS', 'SQL'],
#  ['Python', 'R', 'SAS', 'SQL'],
#  ['JavaScript', 'Python'],
#  ['R', 'SQL'],
#  ['Python'],
#  ['Python', 'SQL'],
#  ['Julia', 'Python'],
#  ['Julia', 'Python'],
#  ['Python', 'R', 'SQL'],
#  ['JavaScript', 'Python', 'SQL'],
#  [],
#  ['Python', 'R', 'SQL'],
#  ['Python', 'R', 'SQL'],
#  ['Python', 'SQL'],
#  ['JavaScript', 'Julia', 'Python', 'SQL'],
#  ['Julia', 'Python', 'SQL'],
#  ['Python', 'R', 'SQL'],
#  ['JavaScript', 'Python'],
#  ['Julia', 'MATLAB', 'Python', 'R'],
#  ['Julia', 'Python', 'R', 'SQL'],
#  ['JavaScript', 'Python'],
#  ['Python'],
#  ['Python', 'R', 'SQL'],
#  ['SQL'],
#  ['Python', 'R', 'SAS'],
#  ['Python', 'R', 'SAS', 'SQL'],
#  ['Java', 'Python', 'SQL'],
#  ['JavaScript', 'Python', 'R', 'SQL'],
#  ['MATLAB', 'Python', 'R', 'SQL'],
#  ['Python', 'R', 'SQL'],
#  ['Java', 'JavaScript', 'Python', 'SQL'],
#  ['Java', 'JavaScript'],
#  ['Python', 'R'],
#  ['Python', 'SQL'],
#  ['Go', 'Python'],
#  ['Julia', 'Python'],
#  ['Python', 'SQL'],
#  ['Java'],
#  ['Python'],
#  ['JavaScript', 'SQL'],
#  ['JavaScript', 'Python', 'SQL'],
#  ['Python', 'R', 'SQL'],
#  ['Python', 'R', 'SAS', 'SQL'],
#  [],
#  ['MATLAB', 'Python', 'SQL'],
#  ['Python', 'R'],
#  ['JavaScript', 'Python'],
#  ['Java', 'JavaScript', 'Python', 'Scala', 'SQL'],
#  ['MATLAB', 'Python', 'R', 'SQL'],
#  ['SQL'],
#  ['R', 'SQL'],
#  ['MATLAB', 'Python'],
#  ['SQL'],
#  ['Python', 'SQL'],
#  ['Julia', 'Python', 'R', 'SQL'],
#  ['Java', 'Python', 'R', 'SQL'],
#  ['Python', 'R', 'SQL'],
#  [],
#  ['Python', 'SQL'],
#  ['Python'],
#  ['MATLAB', 'Python', 'SQL'],
#  ['Java', 'SQL'],
#  ['MATLAB', 'Python', 'SQL'],
#  ['Python', 'R', 'SAS', 'SQL'],
#  ['Julia', 'SQL'],
#  ['Python'],
#  ['R', 'SAS', 'SQL'],
#  ['Python', 'SQL'],
#  ['Python', 'SQL'],
#  ['SQL'],
#  ['Python'],
#  ['SQL'],
#  ['Python', 'SQL'],
#  ['Python', 'SQL'],
#  ['Python', 'SQL'],
#  ['Python', 'SQL'],
#  ['Java', 'JavaScript', 'Python', 'Scala', 'SQL'],
#  ['Go', 'Python', 'SQL'],
#  ['Python', 'R'],
#  ['Python'],
#  ['Julia', 'Python', 'R', 'Scala'],
#  ['Go', 'JavaScript', 'Python', 'R', 'SQL'],
#  ['Julia', 'Python', 'R', 'SQL'],
#  ['Go', 'Python'],
#  ['JavaScript', 'Julia', 'Python'],
#  ['Java', 'Python', 'SQL'],
#  ['Java', 'Python', 'SQL'],
#  ['MATLAB', 'Python', 'SQL'],
#  ['JavaScript', 'Python'],
#  ['JavaScript', 'Python', 'R', 'SQL'],
#  ['Python'],
#  ['Python', 'SQL'],
#  ['Python', 'SQL'],
#  ['JavaScript', 'Python', 'SQL'],
#  ['Java', 'Python', 'SQL'],
#  ['Python', 'SQL'],
#  ['Python'],
#  ['Python', 'R', 'SQL'],
#  ['Julia', 'Python', 'R', 'SQL'],
#  ['JavaScript', 'Python', 'SQL'],
#  ['Python'],
#  ['Python', 'R', 'SQL'],
#  ['Python'],
#  ['Java', 'Python', 'SQL'],
#  ['Python', 'R', 'SQL'],
#  ['Python', 'R'],
#  ['JavaScript', 'Python', 'SQL'],
#  ['Python', 'R'],
#  ['Python', 'R'],
#  ['Python', 'SAS', 'SQL'],
#  ['Java', 'JavaScript', 'MATLAB', 'Python', 'R', 'SQL'],
#  ['Java'],
#  ['Go', 'Python', 'Scala', 'SQL'],
#  ['JavaScript', 'Python', 'SQL'],
#  ['Python', 'SQL'],
#  ['Python'],
#  ['JavaScript', 'Python'],
#  ['Python', 'SQL'],
#  ['JavaScript', 'Python', 'SQL'],
#  ['Python', 'SQL'],
#  ['Java', 'JavaScript', 'Python', 'Scala', 'SQL'],
#  ['Python'],
#  ['JavaScript', 'Python'],
#  ['Python', 'SQL'],
#  ['JavaScript', 'Python', 'SQL'],
#  ['Python', 'SQL'],
#  ['Java'],
#  ['Python', 'R', 'SQL'],
#  ['Python'],
#  ['JavaScript', 'Python'],
#  ['JavaScript', 'Python'],
#  ['Python', 'SQL'],
#  ['Python', 'R', 'Scala'],
#  ['Java', 'JavaScript', 'Python'],
#  ['JavaScript', 'Python', 'SQL'],
#  ['Python', 'R', 'SQL'],
#  ['JavaScript', 'Python'],
#  ['Python', 'R', 'SAS', 'SQL'],
#  ['Go', 'Java', 'JavaScript', 'Python', 'SQL'],
#  ['Python', 'R', 'SQL'],
#  ['Python', 'SQL'],
#  ['R'],
#  ['Python', 'SQL'],
#  ['Python'],
#  ['Python'],
#  ['R', 'SQL'],
#  ['Python'],
#  ['Python', 'R', 'SQL'],
#  ['Python', 'SQL'],
#  ['Python', 'SQL'],
#  ['Java', 'JavaScript', 'Python', 'R', 'SAS', 'SQL'],
#  ['R', 'SQL'],
#  ['Python'],
#  ['JavaScript', 'Python'],
#  ['Python'],
#  ['Python', 'R', 'SQL'],
#  ['Python', 'SQL'],
#  ['MATLAB', 'Python', 'Scala', 'SQL'],
#  ['Python', 'SQL'],
#  ['Java', 'JavaScript', 'Python', 'SQL'],
#  ['Python'],
#  ['JavaScript', 'Python', 'SQL'],
#  ['Java', 'JavaScript', 'Python', 'SQL'],
#  ['R'],
#  ['Python'],
#  ['Python'],
#  ['R', 'SQL'],
#  ['Python', 'R', 'SQL'],
#  ['SQL'],
#  ['Python', 'SQL'],
#  ['Java', 'JavaScript', 'SQL'],
#  ['Python'],
#  ['JavaScript', 'Python'],
#  ['JavaScript', 'Python', 'SQL'],
#  ['Python', 'R', 'SQL'],
#  ['SQL'],
#  ['Python', 'SQL'],
#  ['R'],
#  ['Python'],
#  [],
#  ['Java', 'SQL'],
#  ['JavaScript'],
#  ['Python'],
#  ['Python', 'SQL'],
#  ['Python'],
#  ['Python'],
#  ['JavaScript', 'Python', 'SQL'],
#  ['JavaScript', 'MATLAB', 'Python', 'SQL'],
#  ['Python', 'R'],
#  ['Python', 'SQL'],
#  ['Python', 'R', 'SQL'],
#  ['Java', 'JavaScript', 'Python', 'R', 'SQL'],
#  ['Julia', 'Python', 'R'],
#  ['Python', 'SQL'],
#  ['Python'],
#  ['Python'],
#  ['Java', 'Python', 'R', 'SQL'],
#  ['Python', 'SQL'],
#  ['MATLAB', 'Python', 'R', 'SQL'],
#  ['JavaScript', 'Python'],
#  ['Python'],
#  ['Go', 'Python'],
#  ['Python', 'SQL'],
#  ['MATLAB', 'Python', 'R', 'SQL'],
#  ['Python', 'R'],
#  ['Java', 'JavaScript', 'MATLAB', 'Python', 'SQL'],
#  ['Java', 'JavaScript', 'Python'],
#  ['Python', 'SQL'],
#  ['R', 'SQL'],
#  ['Python', 'R', 'SQL'],
#  ['Python', 'SQL'],
#  ['Python', 'SQL'],
#  ['Python', 'SQL'],
#  ['Python'],
#  ['R', 'SQL'],
#  ['Python', 'R', 'SQL'],
#  ['JavaScript', 'Julia', 'Python'],
#  ['Java', 'JavaScript', 'Python'],
#  ['SQL'],
#  ['Python', 'R', 'SQL'],
#  ['JavaScript', 'Julia', 'Python', 'R', 'SQL'],
#  ['JavaScript', 'Python', 'R', 'SQL'],
#  ['JavaScript', 'Python'],
#  ['Python'],
#  ['Java', 'Python', 'Scala'],
#  ['Python', 'SQL'],
#  ['Python'],
#  ['SQL'],
#  ['Python'],
#  ['Python'],
#  ['Python', 'R', 'SQL'],
#  ['Python'],
#  ['Java', 'Python'],
#  ['JavaScript'],
#  ['Python'],
#  ['Python', 'SQL'],
#  ['Python'],
#  ['Python', 'R', 'SQL'],
#  ['Python', 'R', 'SQL'],
#  ['JavaScript', 'Python', 'R', 'SQL'],
#  ['JavaScript', 'Julia', 'Python', 'R', 'SQL'],
#  ['R'],
#  ['Python', 'SQL'],
#  ['Python'],
#  ['JavaScript', 'Julia', 'Python'],
#  ['Python'],
#  ['Python', 'SQL'],
#  ['Python', 'SQL'],
#  ['Python'],
#  ['R'],
#  ['Python', 'R', 'SQL'],
#  ['Python', 'R', 'SQL'],
#  ['Python', 'SQL'],
#  ['Python', 'R', 'SQL'],
#  ['Python', 'SQL'],
#  ['R'],
#  ['Python', 'R', 'SQL'],
#  ['SQL'],
#  ['Python'],
#  ['Python', 'SQL'],
#  ['Python', 'SQL'],
#  ['Python', 'R'],
#  ['JavaScript', 'Python', 'SQL'],
#  ['Python'],
#  ['Python', 'SQL'],
#  ['Python'],
#  ['Java', 'SQL'],
#  ['SQL'],
#  ['Python', 'R', 'SQL'],
#  ['JavaScript', 'Python', 'SQL'],
#  ['Java', 'JavaScript', 'Python', 'Scala', 'SQL'],
#  ['Python'],
#  ['SAS', 'SQL'],
#  ['R'],
#  ['Java', 'Python'],
#  ['Python', 'SQL'],
#  ['Python'],
#  ['Python', 'R', 'Scala', 'SQL'],
#  ['Python', 'R', 'SQL'],
#  ['Python', 'R', 'SQL'],
#  [],
#  ['JavaScript', 'Python'],
#  ['JavaScript', 'Python', 'SQL'],
#  ['Python', 'SQL'],
#  ['JavaScript', 'Python', 'R', 'SQL'],
#  ['Python', 'R', 'SQL'],
#  ['Python'],
#  ['Python'],
#  ['Julia', 'Python', 'R', 'SQL'],
#  ['Python'],
#  ['Java', 'SQL'],
#  ['JavaScript', 'Python', 'SQL'],
#  ['Python'],
#  ['MATLAB', 'Python', 'SQL'],
#  ['Python'],
#  ['Python'],
#  ['JavaScript', 'MATLAB', 'Python', 'R', 'SQL'],
#  ['Java', 'Python', 'SQL'],
#  [],
#  ['Julia', 'Python', 'Scala', 'SQL'],
#  ['Java', 'JavaScript', 'Python'],
#  ['JavaScript', 'SQL'],
#  ['Go', 'Python', 'R', 'Scala', 'SQL'],
#  ['Python', 'R', 'SQL'],
#  ['Java', 'JavaScript', 'Python', 'R', 'SQL'],
#  ['JavaScript', 'R', 'SQL'],
#  ['Python', 'SQL'],
#  ['Python', 'SQL'],
#  ['SQL'],
#  ['Python', 'SQL'],
#  ['Python', 'SQL'],
#  ['Python'],
#  ['MATLAB', 'Python', 'R', 'SQL'],
#  ['Python', 'Scala'],
#  ['Python'],
#  ['Java', 'Python'],
#  ['Go', 'Python', 'R', 'SQL'],
#  ['Python', 'SQL'],
#  ['Python', 'SQL'],
#  ['Python', 'SQL'],
#  ['R'],
#  ['Python', 'SQL'],
#  ['Java', 'Python', 'SQL'],
#  ['Python', 'R', 'Scala'],
#  ['Python'],
#  ['Java', 'JavaScript', 'Python', 'R', 'Scala', 'SQL'],
#  ['Python', 'SAS', 'SQL'],
#  ['Python'],
#  ['Python'],
#  ['Python', 'R'],
#  ['MATLAB', 'Python'],
#  ['Go', 'Java', 'JavaScript', 'Python'],
#  ['Python', 'R', 'SQL'],
#  ['Python', 'SQL'],
#  ['JavaScript', 'Python', 'R', 'SQL'],
#  [],
#  ['Python', 'SQL'],
#  ['R', 'SQL'],
#  ['JavaScript', 'Python', 'SQL'],
#  ['Python', 'SQL'],
#  ['Python'],
#  ['Java', 'Python'],
#  ['Go', 'Java', 'JavaScript', 'Python'],
#  ['Python', 'SQL'],
#  ['Java', 'R', 'SQL'],
#  ['Python'],
#  ['Python', 'R', 'SQL'],
#  ['Java', 'JavaScript', 'Python', 'Scala', 'SQL'],
#  ['Python', 'SQL'],
#  ['Python', 'SQL'],
#  ['Python', 'SQL'],
#  ['Python', 'R', 'SQL'],
#  ['JavaScript', 'Python', 'SQL'],
#  ['Python', 'SQL'],
#  ['Python', 'SQL'],
#  ['Python', 'SQL'],
#  ['Python'],
#  ['JavaScript', 'Python', 'R', 'SQL'],
#  ['Python'],
#  ['Python'],
#  ['Julia', 'Python'],
#  ['JavaScript', 'Python', 'SQL'],
#  ['Python', 'SQL'],
#  ['Java', 'Python', 'R'],
#  ['Python'],
#  ['Python'],
#  ['Python', 'SQL'],
#  ['Python', 'SQL'],
#  ['Java', 'Python', 'SQL'],
#  ['JavaScript', 'Python', 'R', 'SQL'],
#  ['JavaScript', 'Python', 'R', 'SQL'],
#  ['Python', 'SQL'],
#  ['Java', 'JavaScript', 'Python', 'SQL'],
#  ['Python', 'R', 'SQL'],
#  ['Python', 'SQL'],
#  ['Python', 'SQL'],
#  ['Java', 'JavaScript', 'Python', 'R', 'SQL'],
#  ['Python'],
#  ['Java', 'JavaScript', 'Python'],
#  ['SQL'],
#  ['Julia', 'Python', 'R', 'SQL'],
#  ['JavaScript', 'Python', 'SQL'],
#  ['Java', 'Python', 'SQL'],
#  ['Python', 'R', 'SQL'],
#  ['Python', 'R'],
#  ['Python', 'R'],
#  ['Python', 'SQL'],
#  ['JavaScript', 'Python', 'SQL'],
#  ['Python'],
#  ['Python'],
#  ['Java', 'JavaScript', 'Python', 'SQL'],
#  ['Python', 'SQL'],
#  ['Python'],
#  ['JavaScript', 'Python', 'SQL'],
#  ['JavaScript', 'SQL'],
#  ['SQL'],
#  ['Python', 'SQL'],
#  ['Python'],
#  ['JavaScript', 'Python', 'SQL'],
#  ['JavaScript', 'Python'],
#  ['Python'],
#  ['Python'],
#  ['Python', 'R'],
#  ['Python'],
#  ['Python'],
#  ['JavaScript', 'Python'],
#  ['JavaScript', 'Python', 'SQL'],
#  ['Python'],
#  ['Julia', 'R', 'SQL'],
#  ['JavaScript', 'Python'],
#  ['Python'],
#  ['Python', 'R', 'SQL'],
#  ['Python', 'SQL'],
#  ['JavaScript', 'Python', 'SAS', 'SQL'],
#  ['JavaScript'],
#  ['JavaScript'],
#  ['JavaScript', 'Python', 'R', 'SQL'],
#  ['MATLAB', 'Python', 'R', 'SAS', 'SQL'],
#  ['Go', 'Java', 'Python', 'SQL'],
#  ['Scala'],
#  ['SQL'],
#  ['Java', 'JavaScript', 'MATLAB', 'Python', 'SQL'],
#  ['Python', 'R', 'SQL'],
#  ['MATLAB', 'Python', 'R', 'SAS', 'Scala', 'SQL'],
#  ['Python', 'SQL'],
#  ['Python', 'R', 'SQL'],
#  ['Python'],
#  ['Java', 'Python', 'SQL'],
#  ['Java', 'Python'],
#  ['Python', 'SQL'],
#  ['Python'],
#  ['Python', 'R', 'SQL'],
#  ['R', 'SAS', 'SQL'],
#  ['JavaScript', 'Python', 'SQL'],
#  [],
#  ['Python', 'R'],
#  ['Python', 'R', 'SAS', 'SQL'],
#  ['Julia', 'Python'],
#  ['R', 'SQL'],
#  ['Go', 'JavaScript', 'Python', 'SQL'],
#  ['Python', 'SQL'],
#  ['Python', 'R', 'SQL'],
#  ['Python'],
#  ['Python', 'R', 'SAS', 'SQL'],
#  ['MATLAB', 'Python', 'R', 'SAS', 'SQL'],
#  [],
#  ['Python'],
#  ['Python', 'R'],
#  ['Go', 'JavaScript', 'Julia', 'Python', 'R', 'SAS', 'SQL'],
#  ['Python'],
#  [],
#  ['Python', 'SQL'],
#  ['Python', 'SQL'],
#  ['Java', 'JavaScript', 'Python', 'R', 'SQL'],
#  ['Python', 'R'],
#  ['R'],
#  ['Java', 'JavaScript', 'Python', 'SQL'],
#  ['Python'],
#  ['Python'],
#  ['SQL'],
#  ['Java', 'Python'],
#  ['JavaScript', 'Python', 'SQL'],
#  ['JavaScript', 'Python', 'SQL'],
#  ['MATLAB', 'Python'],
#  ['Java', 'Python', 'SAS', 'SQL'],
#  ['Python', 'SQL'],
#  ['Python'],
#  ['JavaScript', 'Python', 'SQL'],
#  ['Java', 'JavaScript', 'Python', 'R', 'Scala', 'SQL'],
#  ['Java', 'Python', 'R', 'Scala'],
#  ['JavaScript', 'Python', 'R', 'SQL'],
#  ['Python', 'R', 'SQL'],
#  ['JavaScript', 'Python', 'R', 'SQL'],
#  ['Python', 'SQL'],
#  ['JavaScript', 'SQL'],
#  ['R', 'SAS', 'SQL'],
#  ['Julia', 'R'],
#  ['JavaScript', 'Python', 'SQL'],
#  ['Python', 'SQL'],
#  ['Java', 'JavaScript', 'Python', 'SQL'],
#  ['Go', 'JavaScript', 'Python', 'SQL'],
#  ['Python'],
#  ['R'],
#  ['Python', 'R', 'SQL'],
#  ['Python', 'SAS', 'SQL'],
#  ['R', 'SQL'],
#  ['Python'],
#  ['JavaScript', 'Python', 'SQL'],
#  ['Python', 'SQL'],
#  ['Java', 'JavaScript', 'MATLAB', 'Python', 'SQL'],
#  ['MATLAB', 'Python'],
#  ['Python', 'R', 'Scala'],
#  ['Python'],
#  ['SAS', 'SQL'],
#  ['Python', 'SQL'],
#  ['Python'],
#  ['JavaScript', 'Python', 'R', 'Scala', 'SQL'],
#  ['Python', 'SQL'],
#  ['Python'],
#  ['JavaScript', 'Python', 'SQL'],
#  ['JavaScript', 'Python', 'R', 'SQL'],
#  ['R', 'SQL'],
#  ['Python', 'R', 'SQL'],
#  ['Python', 'R', 'SQL'],
#  ['Python', 'R', 'SQL'],
#  ['Python', 'SQL'],
#  ['Python'],
#  ['Python', 'SQL'],
#  ['SQL'],
#  ['JavaScript', 'MATLAB', 'Python', 'R', 'SQL'],
#  ['Python'],
#  ['MATLAB', 'Python', 'SQL'],
#  ['Python'],
#  ['Python', 'SQL'],
#  ['JavaScript', 'Python', 'SAS', 'SQL'],
#  ['Python', 'SQL'],
#  ['MATLAB', 'Python'],
#  ['MATLAB', 'Python', 'SQL'],
#  ['Python', 'SQL'],
#  ['Julia'],
#  ['Python', 'SQL'],
#  ['JavaScript', 'Python', 'SQL'],
#  ['Python', 'SQL'],
#  ['JavaScript'],
#  ['Python'],
#  ['Python'],
#  ['Java', 'JavaScript', 'Python'],
#  ['Java', 'JavaScript', 'Python'],
#  ['Python'],
#  ['MATLAB', 'Python'],
#  ['Julia', 'R'],
#  ['Python', 'SQL'],
#  ['Python', 'SQL'],
#  ['SQL'],
#  ['Python', 'SQL'],
#  ['R'],
#  ['R', 'SQL'],
#  ['Python'],
#  ['JavaScript', 'Julia', 'Python'],
#  ['JavaScript', 'SQL'],
#  ['Python', 'Scala', 'SQL'],
#  ['Java', 'JavaScript', 'Python', 'SQL'],
#  ['Python', 'SQL'],
#  ['Go', 'JavaScript', 'Python', 'R', 'SQL'],
#  ['JavaScript', 'Python'],
#  ['Python', 'SQL'],
#  ['SQL'],
#  ['Julia', 'MATLAB', 'Python', 'R', 'SAS', 'SQL'],
#  ['Python', 'SQL'],
#  ['Python', 'SQL'],
#  ['SQL'],
#  ['JavaScript', 'Python', 'SQL'],
#  ['Java', 'JavaScript', 'MATLAB', 'Python'],
#  ['Python'],
#  ['R'],
#  ['Python', 'SQL'],
#  ['Python', 'SQL'],
#  ['R', 'SQL'],
#  ['JavaScript', 'Python', 'SQL'],
#  ['Python', 'R'],
#  ['Python'],
#  ['Python', 'SQL'],
#  ['Python', 'R'],
#  ['SQL'],
#  ['Java', 'Python'],
#  ['Python'],
#  ['Python', 'SQL'],
#  ['Python', 'R', 'SQL'],
#  ['Python', 'R', 'SQL'],
#  ['Java', 'JavaScript', 'Python', 'SQL'],
#  ['Java', 'Python'],
#  ['MATLAB', 'Python', 'R'],
#  ['JavaScript', 'Python', 'R', 'Scala', 'SQL'],
#  ['JavaScript', 'Python'],
#  ['Python', 'SQL'],
#  ['Python', 'R', 'SQL'],
#  ['Python', 'R'],
#  ['JavaScript', 'Python', 'SQL'],
#  ['Python'],
#  ['Python', 'SQL'],
#  ['MATLAB', 'Python', 'SQL'],
#  ['Python', 'SQL'],
#  ['Java', 'SQL'],
#  ['Python', 'SQL'],
#  ['Python'],
#  ['Python', 'R', 'SQL'],
#  ['JavaScript', 'Python'],
#  ['Go', 'Python'],
#  ['R', 'SQL'],
#  ['Python', 'SQL'],
#  ['Python', 'SQL'],
#  ['R', 'SQL'],
#  ['MATLAB', 'Python', 'R', 'SQL'],
#  ['Python'],
#  ['Python'],
#  ['Python', 'SQL'],
#  ['R'],
#  ['Java', 'Python', 'Scala', 'SQL'],
#  ['Julia', 'R', 'SQL'],
#  ['JavaScript', 'Python', 'SQL']]

# %%
te = TransactionEncoder()
te_ary = te.fit(revised_lang_list).transform(revised_lang_list)
te_ary
# Out:
# array([[False, False, False, ..., False,  True, False],
#        [False, False, False, ..., False,  True, False],
#        [False, False, False, ..., False,  True, False],
#        ...,
#        [False,  True, False, ..., False,  True,  True],
#        [False, False, False, ..., False,  True, False],
#        [False, False,  True, ..., False,  True, False]], shape=(729, 10))

# %%
new_languages = pd.DataFrame(te_ary, columns=te.columns_)
new_languages
# Out:
#         Go   Java  JavaScript  Julia  MATLAB  Python      R    SAS    SQL  \
# 0    False  False       False  False   False    True  False  False   True
# 1    False  False       False  False   False    True  False  False   True
# 2    False  False       False  False   False    True  False  False   True
# 3    False  False       False  False   False    True  False  False  False
# 4    False  False       False  False   False    True  False  False   True
# ..     ...    ...         ...    ...     ...     ...    ...    ...    ...
# 724  False  False       False  False   False    True  False  False   True
# 725  False  False       False  False   False   False   True  False  False
# 726  False   True       False  False   False    True  False  False   True
# 727  False  False       False   True   False   False   True  False   True
# 728  False  False        True  False   False    True  False  False   True
#
#      Scala
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# ..     ...
# 724  False
# 725  False
# 726   True
# 727  False
# 728  False
#
# [729 rows x 10 columns]

# %%
freq_items = apriori(new_languages, min_support=0.01, use_colnames=True, verbose=1)
# Out:
# Processing 55 combinations | Sampling itemset size 54

# %%
freq_items.sort_values(['support'], ascending=False).head(20)
# Out:
#      support                    itemsets
# 5   0.855967                    (Python)
# 8   0.603567                       (SQL)
# 32  0.517147               (SQL, Python)
# 6   0.292181                         (R)
# 30  0.237311                 (Python, R)
# 2   0.231824                (JavaScript)
# 35  0.213992                    (SQL, R)
# 20  0.211248        (Python, JavaScript)
# 64  0.182442            (SQL, Python, R)
# 22  0.160494           (SQL, JavaScript)
# 53  0.148148   (SQL, Python, JavaScript)
# 1   0.116598                      (Java)
# 14  0.098765              (Python, Java)
# 16  0.076818                 (SQL, Java)
# 45  0.065844         (SQL, Python, Java)
# 13  0.064472          (JavaScript, Java)
# 41  0.060357  (Python, JavaScript, Java)
# 27  0.056241            (Python, MATLAB)
# 4   0.056241                    (MATLAB)
# 3   0.053498                     (Julia)

# %%
freq_items['length'] = freq_items['itemsets'].apply(lambda x: len(x))
freq_items
# Out:
#      support                            itemsets  length
# 0   0.030178                                (Go)       1
# 1   0.116598                              (Java)       1
# 2   0.231824                        (JavaScript)       1
# 3   0.053498                             (Julia)       1
# 4   0.056241                            (MATLAB)       1
# ..       ...                                 ...     ...
# 78  0.017833             (Julia, SQL, Python, R)       4
# 79  0.019204            (SQL, Python, R, MATLAB)       4
# 80  0.021948               (SQL, Python, R, SAS)       4
# 81  0.012346             (SQL, Python, R, Scala)       4
# 82  0.013717  (Python, R, Java, JavaScript, SQL)       5
#
# [83 rows x 3 columns]

# %%
rules = association_rules(freq_items, min_threshold=0.01)
rules['antecedents_str'] = rules['antecedents'].apply(lambda x: ','.join(list(x)))
rules['consequents_str'] = rules['consequents'].apply(lambda x: ','.join(list(x)))
rules
# Out:
#       antecedents                      consequents  antecedent support  \
# 0            (Go)                     (JavaScript)            0.030178
# 1    (JavaScript)                             (Go)            0.231824
# 2            (Go)                         (Python)            0.030178
# 3        (Python)                             (Go)            0.855967
# 4            (Go)                            (SQL)            0.030178
# ..            ...                              ...                 ...
# 437      (Python)       (JavaScript, SQL, R, Java)            0.855967
# 438           (R)  (SQL, Python, JavaScript, Java)            0.292181
# 439        (Java)     (JavaScript, SQL, Python, R)            0.116598
# 440  (JavaScript)           (SQL, Python, R, Java)            0.231824
# 441         (SQL)    (JavaScript, Python, R, Java)            0.603567
#
#      consequent support   support  confidence      lift  representativity  \
# 0              0.231824  0.013717    0.454545  1.960732               1.0
# 1              0.030178  0.013717    0.059172  1.960732               1.0
# 2              0.855967  0.028807    0.954545  1.115166               1.0
# 3              0.030178  0.028807    0.033654  1.115166               1.0
# 4              0.603567  0.017833    0.590909  0.979029               1.0
# ..                  ...       ...         ...       ...               ...
# 437            0.013717  0.013717    0.016026  1.168269               1.0
# 438            0.043896  0.013717    0.046948  1.069542               1.0
# 439            0.048011  0.013717    0.117647  2.450420               1.0
# 440            0.016461  0.013717    0.059172  3.594675               1.0
# 441            0.013717  0.013717    0.022727  1.656818               1.0
#
#      leverage  conviction  zhangs_metric   jaccard  certainty  kulczynski  \
# 0    0.006721    1.408322       0.505233  0.055249   0.289935    0.256859
# 1    0.006721    1.030817       0.637857  0.055249   0.029895    0.256859
# 2    0.002975    3.168724       0.106486  0.033600   0.684416    0.494100
# 3    0.002975    1.003597       0.717007  0.033600   0.003584    0.494100
# 4   -0.000382    0.969060      -0.021610  0.028953  -0.031928    0.310227
# ..        ...         ...            ...       ...        ...         ...
# 437  0.001976    1.002346       1.000000  0.016026   0.002340    0.508013
# 438  0.000892    1.003203       0.091860  0.042553   0.003193    0.179724
# 439  0.008119    1.078921       0.670031  0.090909   0.073148    0.201681
# 440  0.009901    1.045397       0.939643  0.058480   0.043426    0.446252
# 441  0.005438    1.009219       1.000000  0.022727   0.009135    0.511364
#
#     antecedents_str             consequents_str
# 0                Go                  JavaScript
# 1        JavaScript                          Go
# 2                Go                      Python
# 3            Python                          Go
# 4                Go                         SQL
# ..              ...                         ...
# 437          Python       JavaScript,SQL,R,Java
# 438               R  SQL,Python,JavaScript,Java
# 439            Java     JavaScript,SQL,Python,R
# 440      JavaScript           SQL,Python,R,Java
# 441             SQL    JavaScript,Python,R,Java
#
# [442 rows x 16 columns]

# %%
rules_for_python = rules[rules.apply(lambda x: ('Python' in x['antecedents'] and len(x['antecedents']) == 1), axis=1)]
rules_for_python.head(20)
# Out:
#     antecedents           consequents  antecedent support  consequent support  \
# 3      (Python)                  (Go)            0.855967            0.030178
# 8      (Python)                (Java)            0.855967            0.116598
# 20     (Python)          (JavaScript)            0.855967            0.231824
# 29     (Python)               (Julia)            0.855967            0.053498
# 34     (Python)              (MATLAB)            0.855967            0.056241
# 40     (Python)                   (R)            0.855967            0.292181
# 42     (Python)                 (SAS)            0.855967            0.045267
# 45     (Python)                 (SQL)            0.855967            0.603567
# 46     (Python)               (Scala)            0.855967            0.039781
# 62     (Python)      (Go, JavaScript)            0.855967            0.013717
# 69     (Python)             (Go, SQL)            0.855967            0.017833
# 73     (Python)    (JavaScript, Java)            0.855967            0.064472
# 91     (Python)             (R, Java)            0.855967            0.020576
# 98     (Python)           (SQL, Java)            0.855967            0.076818
# 104    (Python)         (Scala, Java)            0.855967            0.013717
# 122    (Python)   (Julia, JavaScript)            0.855967            0.012346
# 127    (Python)  (JavaScript, MATLAB)            0.855967            0.012346
# 140    (Python)       (R, JavaScript)            0.855967            0.049383
# 146    (Python)     (SQL, JavaScript)            0.855967            0.160494
# 151    (Python)   (JavaScript, Scala)            0.855967            0.012346
#
#       support  confidence      lift  representativity  leverage  conviction  \
# 3    0.028807    0.033654  1.115166               1.0  0.002975    1.003597
# 8    0.098765    0.115385  0.989593               1.0 -0.001039    0.998628
# 20   0.211248    0.246795  1.064577               1.0  0.012814    1.019876
# 29   0.043896    0.051282  0.958580               1.0 -0.001897    0.997664
# 34   0.056241    0.065705  1.168269               1.0  0.008101    1.010129
# 40   0.237311    0.277244  0.948876               1.0 -0.012786    0.979333
# 42   0.037037    0.043269  0.955857               1.0 -0.001710    0.997911
# 45   0.517147    0.604167  1.000994               1.0  0.000514    1.001516
# 46   0.038409    0.044872  1.127984               1.0  0.004358    1.005330
# 62   0.013717    0.016026  1.168269               1.0  0.001976    1.002346
# 69   0.017833    0.020833  1.168269               1.0  0.002568    1.003065
# 73   0.060357    0.070513  1.093699               1.0  0.005171    1.006499
# 91   0.019204    0.022436  1.090385               1.0  0.001592    1.001902
# 98   0.065844    0.076923  1.001374               1.0  0.000090    1.000114
# 104  0.013717    0.016026  1.168269               1.0  0.001976    1.002346
# 122  0.012346    0.014423  1.168269               1.0  0.001778    1.002108
# 127  0.012346    0.014423  1.168269               1.0  0.001778    1.002108
# 140  0.048011    0.056090  1.135817               1.0  0.005741    1.007106
# 146  0.148148    0.173077  1.078402               1.0  0.010771    1.015217
# 151  0.012346    0.014423  1.168269               1.0  0.001778    1.002108
#
#      zhangs_metric   jaccard  certainty  kulczynski antecedents_str  \
# 3         0.717007  0.033600   0.003584    0.494100          Python
# 8        -0.068047  0.113030  -0.001374    0.481222          Python
# 20        0.421150  0.241002   0.019488    0.579019          Python
# 29       -0.230769  0.050713  -0.002341    0.435897          Python
# 34        1.000000  0.065705   0.010028    0.532853          Python
# 40       -0.272236  0.260542  -0.021104    0.544725          Python
# 42       -0.242788  0.042857  -0.002093    0.430726          Python
# 45        0.006897  0.548763   0.001514    0.730492          Python
# 46        0.787755  0.044800   0.005302    0.505195          Python
# 62        1.000000  0.016026   0.002340    0.508013          Python
# 69        1.000000  0.020833   0.003055    0.510417          Python
# 73        0.594805  0.070175   0.006457    0.503342          Python
# 91        0.575510  0.022400   0.001899    0.477885          Python
# 98        0.009524  0.075949   0.000114    0.467033          Python
# 104       1.000000  0.016026   0.002340    0.508013          Python
# 122       1.000000  0.014423   0.002103    0.507212          Python
# 127       1.000000  0.014423   0.002103    0.507212          Python
# 140       0.830204  0.056000   0.007055    0.514156          Python
# 146       0.504762  0.170616   0.014989    0.548077          Python
# 151       1.000000  0.014423   0.002103    0.507212          Python
#
#        consequents_str
# 3                   Go
# 8                 Java
# 20          JavaScript
# 29               Julia
# 34              MATLAB
# 40                   R
# 42                 SAS
# 45                 SQL
# 46               Scala
# 62       Go,JavaScript
# 69              Go,SQL
# 73     JavaScript,Java
# 91              R,Java
# 98            SQL,Java
# 104         Scala,Java
# 122   Julia,JavaScript
# 127  JavaScript,MATLAB
# 140       R,JavaScript
# 146     SQL,JavaScript
# 151   JavaScript,Scala

# %%
high_lift_rules_for_python = rules_for_python[rules_for_python['lift'] > 0]
high_lift_rules_for_python
# Out:
#     antecedents                 consequents  antecedent support  \
# 3      (Python)                        (Go)            0.855967
# 8      (Python)                      (Java)            0.855967
# 20     (Python)                (JavaScript)            0.855967
# 29     (Python)                     (Julia)            0.855967
# 34     (Python)                    (MATLAB)            0.855967
# 40     (Python)                         (R)            0.855967
# 42     (Python)                       (SAS)            0.855967
# 45     (Python)                       (SQL)            0.855967
# 46     (Python)                     (Scala)            0.855967
# 62     (Python)            (Go, JavaScript)            0.855967
# 69     (Python)                   (Go, SQL)            0.855967
# 73     (Python)          (JavaScript, Java)            0.855967
# 91     (Python)                   (R, Java)            0.855967
# 98     (Python)                 (SQL, Java)            0.855967
# 104    (Python)               (Scala, Java)            0.855967
# 122    (Python)         (Julia, JavaScript)            0.855967
# 127    (Python)        (JavaScript, MATLAB)            0.855967
# 140    (Python)             (R, JavaScript)            0.855967
# 146    (Python)           (SQL, JavaScript)            0.855967
# 151    (Python)         (JavaScript, Scala)            0.855967
# 170    (Python)                  (Julia, R)            0.855967
# 177    (Python)                (Julia, SQL)            0.855967
# 187    (Python)                 (R, MATLAB)            0.855967
# 194    (Python)               (SQL, MATLAB)            0.855967
# 205    (Python)                    (R, SAS)            0.855967
# 212    (Python)                    (SQL, R)            0.855967
# 217    (Python)                  (R, Scala)            0.855967
# 224    (Python)                  (SQL, SAS)            0.855967
# 230    (Python)                (SQL, Scala)            0.855967
# 255    (Python)       (R, JavaScript, Java)            0.855967
# 269    (Python)     (SQL, JavaScript, Java)            0.855967
# 297    (Python)              (SQL, R, Java)            0.855967
# 312    (Python)          (SQL, Scala, Java)            0.855967
# 325    (Python)   (SQL, JavaScript, MATLAB)            0.855967
# 340    (Python)        (R, SQL, JavaScript)            0.855967
# 353    (Python)    (SQL, JavaScript, Scala)            0.855967
# 368    (Python)             (Julia, SQL, R)            0.855967
# 381    (Python)            (SQL, R, MATLAB)            0.855967
# 395    (Python)               (SQL, R, SAS)            0.855967
# 409    (Python)             (SQL, R, Scala)            0.855967
# 437    (Python)  (JavaScript, SQL, R, Java)            0.855967
#
#      consequent support   support  confidence      lift  representativity  \
# 3              0.030178  0.028807    0.033654  1.115166               1.0
# 8              0.116598  0.098765    0.115385  0.989593               1.0
# 20             0.231824  0.211248    0.246795  1.064577               1.0
# 29             0.053498  0.043896    0.051282  0.958580               1.0
# 34             0.056241  0.056241    0.065705  1.168269               1.0
# 40             0.292181  0.237311    0.277244  0.948876               1.0
# 42             0.045267  0.037037    0.043269  0.955857               1.0
# 45             0.603567  0.517147    0.604167  1.000994               1.0
# 46             0.039781  0.038409    0.044872  1.127984               1.0
# 62             0.013717  0.013717    0.016026  1.168269               1.0
# 69             0.017833  0.017833    0.020833  1.168269               1.0
# 73             0.064472  0.060357    0.070513  1.093699               1.0
# 91             0.020576  0.019204    0.022436  1.090385               1.0
# 98             0.076818  0.065844    0.076923  1.001374               1.0
# 104            0.013717  0.013717    0.016026  1.168269               1.0
# 122            0.012346  0.012346    0.014423  1.168269               1.0
# 127            0.012346  0.012346    0.014423  1.168269               1.0
# 140            0.049383  0.048011    0.056090  1.135817               1.0
# 146            0.160494  0.148148    0.173077  1.078402               1.0
# 151            0.012346  0.012346    0.014423  1.168269               1.0
# 170            0.028807  0.023320    0.027244  0.945742               1.0
# 177            0.028807  0.023320    0.027244  0.945742               1.0
# 187            0.023320  0.023320    0.027244  1.168269               1.0
# 194            0.041152  0.041152    0.048077  1.168269               1.0
# 205            0.028807  0.023320    0.027244  0.945742               1.0
# 212            0.213992  0.182442    0.213141  0.996024               1.0
# 217            0.019204  0.019204    0.022436  1.168269               1.0
# 224            0.043896  0.035665    0.041667  0.949219               1.0
# 230            0.028807  0.028807    0.033654  1.168269               1.0
# 255            0.013717  0.013717    0.016026  1.168269               1.0
# 269            0.046639  0.043896    0.051282  1.099548               1.0
# 297            0.017833  0.016461    0.019231  1.078402               1.0
# 312            0.010974  0.010974    0.012821  1.168269               1.0
# 325            0.010974  0.010974    0.012821  1.168269               1.0
# 340            0.049383  0.048011    0.056090  1.135817               1.0
# 353            0.012346  0.012346    0.014423  1.168269               1.0
# 368            0.020576  0.017833    0.020833  1.012500               1.0
# 381            0.019204  0.019204    0.022436  1.168269               1.0
# 395            0.027435  0.021948    0.025641  0.934615               1.0
# 409            0.012346  0.012346    0.014423  1.168269               1.0
# 437            0.013717  0.013717    0.016026  1.168269               1.0
#
#      leverage  conviction  zhangs_metric   jaccard  certainty  kulczynski  \
# 3    0.002975    1.003597       0.717007  0.033600   0.003584    0.494100
# 8   -0.001039    0.998628      -0.068047  0.113030  -0.001374    0.481222
# 20   0.012814    1.019876       0.421150  0.241002   0.019488    0.579019
# 29  -0.001897    0.997664      -0.230769  0.050713  -0.002341    0.435897
# 34   0.008101    1.010129       1.000000  0.065705   0.010028    0.532853
# 40  -0.012786    0.979333      -0.272236  0.260542  -0.021104    0.544725
# 42  -0.001710    0.997911      -0.242788  0.042857  -0.002093    0.430726
# 45   0.000514    1.001516       0.006897  0.548763   0.001514    0.730492
# 46   0.004358    1.005330       0.787755  0.044800   0.005302    0.505195
# 62   0.001976    1.002346       1.000000  0.016026   0.002340    0.508013
# 69   0.002568    1.003065       1.000000  0.020833   0.003055    0.510417
# 73   0.005171    1.006499       0.594805  0.070175   0.006457    0.503342
# 91   0.001592    1.001902       0.575510  0.022400   0.001899    0.477885
# 98   0.000090    1.000114       0.009524  0.075949   0.000114    0.467033
# 104  0.001976    1.002346       1.000000  0.016026   0.002340    0.508013
# 122  0.001778    1.002108       1.000000  0.014423   0.002103    0.507212
# 127  0.001778    1.002108       1.000000  0.014423   0.002103    0.507212
# 140  0.005741    1.007106       0.830204  0.056000   0.007055    0.514156
# 146  0.010771    1.015217       0.504762  0.170616   0.014989    0.548077
# 151  0.001778    1.002108       1.000000  0.014423   0.002103    0.507212
# 170 -0.001338    0.998393      -0.284856  0.027070  -0.001609    0.418384
# 177 -0.001338    0.998393      -0.284856  0.027070  -0.001609    0.418384
# 187  0.003359    1.004034       1.000000  0.027244   0.004018    0.513622
# 194  0.005927    1.007274       1.000000  0.048077   0.007222    0.524038
# 205 -0.001338    0.998393      -0.284856  0.027070  -0.001609    0.418384
# 212 -0.000728    0.998919      -0.026965  0.205564  -0.001082    0.532853
# 217  0.002766    1.003306       1.000000  0.022436   0.003295    0.511218
# 224 -0.001908    0.997674      -0.270833  0.041270  -0.002331    0.427083
# 230  0.004149    1.005016       1.000000  0.033654   0.004991    0.516827
# 255  0.001976    1.002346       1.000000  0.016026   0.002340    0.508013
# 269  0.003974    1.004894       0.628571  0.051118   0.004870    0.496229
# 297  0.001197    1.001426       0.504762  0.019200   0.001424    0.471154
# 312  0.001581    1.001871       1.000000  0.012821   0.001867    0.506410
# 325  0.001581    1.001871       1.000000  0.012821   0.001867    0.506410
# 340  0.005741    1.007106       0.830204  0.056000   0.007055    0.514156
# 353  0.001778    1.002108       1.000000  0.014423   0.002103    0.507212
# 368  0.000220    1.000263       0.085714  0.020767   0.000263    0.443750
# 381  0.002766    1.003306       1.000000  0.022436   0.003295    0.511218
# 395 -0.001535    0.998159      -0.326923  0.025478  -0.001844    0.412821
# 409  0.001778    1.002108       1.000000  0.014423   0.002103    0.507212
# 437  0.001976    1.002346       1.000000  0.016026   0.002340    0.508013
#
#     antecedents_str        consequents_str
# 3            Python                     Go
# 8            Python                   Java
# 20           Python             JavaScript
# 29           Python                  Julia
# 34           Python                 MATLAB
# 40           Python                      R
# 42           Python                    SAS
# 45           Python                    SQL
# 46           Python                  Scala
# 62           Python          Go,JavaScript
# 69           Python                 Go,SQL
# 73           Python        JavaScript,Java
# 91           Python                 R,Java
# 98           Python               SQL,Java
# 104          Python             Scala,Java
# 122          Python       Julia,JavaScript
# 127          Python      JavaScript,MATLAB
# 140          Python           R,JavaScript
# 146          Python         SQL,JavaScript
# 151          Python       JavaScript,Scala
# 170          Python                Julia,R
# 177          Python              Julia,SQL
# 187          Python               R,MATLAB
# 194          Python             SQL,MATLAB
# 205          Python                  R,SAS
# 212          Python                  SQL,R
# 217          Python                R,Scala
# 224          Python                SQL,SAS
# 230          Python              SQL,Scala
# 255          Python      R,JavaScript,Java
# 269          Python    SQL,JavaScript,Java
# 297          Python             SQL,R,Java
# 312          Python         SQL,Scala,Java
# 325          Python  SQL,JavaScript,MATLAB
# 340          Python       R,SQL,JavaScript
# 353          Python   SQL,JavaScript,Scala
# 368          Python            Julia,SQL,R
# 381          Python           SQL,R,MATLAB
# 395          Python              SQL,R,SAS
# 409          Python            SQL,R,Scala
# 437          Python  JavaScript,SQL,R,Java

# %%
fig=px.scatter(
    high_lift_rules_for_python,
    x = 'support', 
    y = 'confidence', 
    size = 'lift', 
    color= 'lift',
    hover_data=['antecedents_str', 'consequents_str']
)

fig.update_layout(
    xaxis_title='support',
    yaxis_title='confidence',
   
    font_family='Courier New',
    font_color='blue',
    title_font_family='Times New Roman',
    title_font_color='red',
    title=('Support vs Confidence')
    
)

fig.show()

# %%
high_lift_rules_for_python['consequents_str'].info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 41 entries, 3 to 437
# Series name: consequents_str
# Non-Null Count  Dtype
# --------------  -----
# 41 non-null     object
# dtypes: object(1)
# memory usage: 656.0+ bytes

# %%
' '.join(high_lift_rules_for_python['consequents_str'])
# Out:
# 'Go Java JavaScript Julia MATLAB R SAS SQL Scala Go,JavaScript Go,SQL JavaScript,Java R,Java SQL,Java Scala,Java Julia,JavaScript JavaScript,MATLAB R,JavaScript SQL,JavaScript JavaScript,Scala Julia,R Julia,SQL R,MATLAB SQL,MATLAB R,SAS SQL,R R,Scala SQL,SAS SQL,Scala R,JavaScript,Java SQL,JavaScript,Java SQL,R,Java SQL,Scala,Java SQL,JavaScript,MATLAB R,SQL,JavaScript SQL,JavaScript,Scala Julia,SQL,R SQL,R,MATLAB SQL,R,SAS SQL,R,Scala JavaScript,SQL,R,Java'

# %%
wordcloud = WordCloud(background_color = 'white').generate(' '.join(high_lift_rules_for_python['consequents_str']))
plt.rcParams['figure.figsize'] = (10, 10)
plt.imshow(wordcloud)
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(399.5), np.float64(199.5), np.float64(-0.5))
