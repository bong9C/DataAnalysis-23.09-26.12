# %%
# set

languages = {'C++', 'python','C','C','python','C++'}
languages
# Out:
# {'C', 'C++', 'python'}

# %%
languages.add('java')
languages
# Out:
# {'C', 'C++', 'java', 'python'}

# %%
languages.remove('C')
languages
# Out:
# {'C++', 'java', 'python'}

# %%
languages.pop()
# Out:
# 'java'

# %%
languages
# Out:
# {'C++', 'python'}

# %%
languages.clear()
languages
# Out:
# set()
