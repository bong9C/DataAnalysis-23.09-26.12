# %%
# 1. 
languages_a = {'C','javascript','python','R','swift','kotlin'}
languages_b = {'C++','java','python','C#','javascript','R'}

# %%
languages_a & languages_b
# Out:
# {'R', 'javascript', 'python'}

# %%
languages_a - languages_b
# Out:
# {'C', 'kotlin', 'swift'}

# %%
languages_b - languages_a
# Out:
# {'C#', 'C++', 'java'}

# %%
languages_a | languages_b
# Out:
# {'C', 'C#', 'C++', 'R', 'java', 'javascript', 'kotlin', 'python', 'swift'}

# %%
# 2.
import random

scores = dict()

for i in range(10, 50):
    scores['S' + str(i)] = random.randrange(50, 100)

scores?
# Out:
# Type:        dict
# String form: {'S10': 93, 'S11': 63, 'S12': 67, 'S13': 67, 'S14': 61, 'S15': 76, 'S16': 59, 'S17': 94, 'S18': 5 <...> S41': 97, 'S42': 52, 'S43': 73, 'S44': 98, 'S45': 82, 'S46': 79, 'S47': 70, 'S48': 82, 'S49': 80}
# Length:      40
# Docstring:
# dict() -> new empty dictionary
# dict(mapping) -> new dictionary initialized from a mapping object's
#     (key, value) pairs
# dict(iterable) -> new dictionary initialized as if via:
#     d = {}
#     for k, v in iterable:
#         d[k] = v
# dict(**kwargs) -> new dictionary initialized with the name=value pairs
#     in the keyword argument list.  For example:  dict(one=1, two=2)

# %%
# 40명 학생 중 최고 득점

max_scores= max(scores.values())
print("최고 점수:",max_scores)

for k, v in scores.items():
    if v == max_scores:
        print("최고 득점자:", k)
# Out:
# 최고 점수: 98
# 최고 득점자: S44

# %%
# 40명 학생 중 평균 점수
avg_scores= sum(scores.values()) / len(scores)
avg_scores
# Out:
# 71.775
